# %% [markdown]
# Import pandas and os

# %%
import pandas as pd
import os

# %% [markdown]
# Load CASAS files function gets all data from all files into a pandas Dataframe

# %%
def load_casas_file(file_path):
    # Load the data from the file into a list of dictionaries
    data = []
    with open(file_path, 'r') as file:
        for line in file:
            # Split each line by spaces to extract the timestamp, sensor ID, and state
            parts = line.strip().split()
            if len(parts) == 4:
                timestamp = parts[0] + ' ' + parts[1]
                sensor_id = parts[2]
                state = parts[3]
                data.append({"Timestamp": timestamp, "Sensor_ID": sensor_id, "State": state})
    # Convert the list of dictionaries into a Pandas DataFrame
    return pd.DataFrame(data)

# %% [markdown]
# Load All CASAS data calls the load_casas_file function for all files in the adlnormal folder

# %%
def load_all_casas_data(folder_path):
    all_data = []
    # Loop through each file in the folder
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.t1') or file_name.endswith('.t2') or file_name.endswith('.t3') or file_name.endswith('.t4') or file_name.endswith('.t5'):  # Check if the file is a data file
            file_path = os.path.join(folder_path, file_name)
            # Load the file and append the DataFrame to the list
            df = load_casas_file(file_path)
            # print(f"DF: {df}")
            all_data.append(df)
    # Concatenate all the DataFrames into one
    return pd.concat(all_data, ignore_index=True)

# Load the data from the 'adlnormal' folder
folder_path = '/Users/harrisonkirstein/Desktop/CSCI 4380 Honors Option Project/adlnormal'
casas_data = load_all_casas_data(folder_path)

# Preview the loaded data
casas_data.head()
# Out:
#                     Timestamp Sensor_ID State
# 0  2008-03-06 10:49:04.664106       M13    ON
# 1  2008-03-06 10:49:09.371153       M14    ON
# 2  2008-03-06 10:49:10.818028       M15    ON
# 3  2008-03-06 10:49:11.674869       M16    ON
# 4  2008-03-06 10:49:13.312534       M16   OFF

# %% [markdown]
# Get Sensor Type function gets the sensor type depending on the first letter of the sensor ID. (I.e M16 sensor ID would be a Motion type)

# %%
def get_sensor_type(sensor_id):
    sensor_mapping = {
        'M': 'Motion',
        'D': 'Door',
        'T': 'Temperature',
        'L': 'Light',
        'I': 'Item'
    }
    # Extract the first character of the sensor ID to determine the type
    sensor_type_code = sensor_id[0]
    # Return the corresponding sensor type, or 'Unknown' if not mapped
    return sensor_mapping.get(sensor_type_code, 'Unknown')

# %% [markdown]
# Get Sensor Location function gets the sensor location depending on the numbers in the sensor ID. This data would be gathered upon setup of the sensors in a Target Home, so mappings here are just an arbitrary example

# %%
def get_sensor_location(sensor_id):
    # Dictionary mapping sensor numbers to locations
    location_mapping = {
        '01': 'Living Room',
        '02': 'Kitchen',
        '03': 'Bedroom 1',
        '04': 'Bedroom 2',
        '05': 'Bathroom',
        '06': 'Hallway',
        '07': 'Garage',
        '08': 'Front Door',
        '09': 'Back Door',
        '10': 'Dining Room',
        '11': 'Office',
        '12': 'Laundry Room',
        '13': 'Basement',
        '14': 'Stairs',
        '15': 'Closet',
        '16': 'Porch',
        '17': 'Attic'
    }
    
    # Extract the numeric part of the sensor ID
    sensor_number = sensor_id[1:].zfill(2)  # Assumes first character is the type, e.g., M, D, T
    
    # Get the location based on the numeric part, or default to "Unknown"
    return location_mapping.get(sensor_number, 'Unknown')

# %% [markdown]
# Timestamp to Words function converts a timestamp into its word format for the TDOST

# %%
from datetime import datetime

def timestamp_to_words(timestamp):
    # Parse the timestamp

    # Attempt to parse with milliseconds first
    try:
        dt = datetime.strptime(timestamp, "%Y-%m-%d %H:%M:%S.%f")
    except ValueError:
        # Fall back to parsing without milliseconds
        dt = datetime.strptime(timestamp, "%Y-%m-%d %H:%M:%S")
            
    # Extract hour, minute, and determine AM/PM
    hour = dt.hour
    minute = dt.minute
    period = "AM" if hour < 12 else "PM"
    
    # Adjust hour for 12-hour format
    hour = hour % 12 or 12  # 0 becomes 12 for AM/PM format

    # Convert hour and minute to words
    hour_text = num_to_words(hour)
    minute_text = num_to_words(minute)

    # Form the final text
    return f"{hour_text} hours {minute_text} minutes {period}"

def num_to_words(n):
    # Dictionary to convert numbers to words for 0-59
    words = {
        0: "zero", 1: "one", 2: "two", 3: "three", 4: "four", 5: "five",
        6: "six", 7: "seven", 8: "eight", 9: "nine", 10: "ten",
        11: "eleven", 12: "twelve", 13: "thirteen", 14: "fourteen",
        15: "fifteen", 16: "sixteen", 17: "seventeen", 18: "eighteen",
        19: "nineteen", 20: "twenty", 21: "twenty-one", 22: "twenty-two",
        23: "twenty-three", 24: "twenty-four", 25: "twenty-five",
        26: "twenty-six", 27: "twenty-seven", 28: "twenty-eight",
        29: "twenty-nine", 30: "thirty", 31: "thirty-one", 32: "thirty-two",
        33: "thirty-three", 34: "thirty-four", 35: "thirty-five",
        36: "thirty-six", 37: "thirty-seven", 38: "thirty-eight",
        39: "thirty-nine", 40: "forty", 41: "forty-one", 42: "forty-two",
        43: "forty-three", 44: "forty-four", 45: "forty-five",
        46: "forty-six", 47: "forty-seven", 48: "forty-eight",
        49: "forty-nine", 50: "fifty", 51: "fifty-one", 52: "fifty-two",
        53: "fifty-three", 54: "fifty-four", 55: "fifty-five",
        56: "fifty-six", 57: "fifty-seven", 58: "fifty-eight",
        59: "fifty-nine"
    }
    return words.get(n, "")

# %%
def generate_tdost_basic_from_df(df):
    descriptions = []
    for index, row in df.iterrows():
        curr_sensor_type = get_sensor_type(row['Sensor_ID'])
        curr_sensor_location = get_sensor_location(row['Sensor_ID'])
        curr_sensor_time = timestamp_to_words(row['Timestamp'])
        curr_sensor_value = row['State']
        description = f"{curr_sensor_type} sensor in {curr_sensor_location} fired with value {curr_sensor_value} at {curr_sensor_time}."
        descriptions.append(description)
    return descriptions

casas_data_tdost_basic = generate_tdost_basic_from_df(casas_data)
casas_data_tdost_basic
# Out:
# ['Motion sensor in Basement fired with value ON at ten hours forty-nine minutes AM.',
#  'Motion sensor in Stairs fired with value ON at ten hours forty-nine minutes AM.',
#  'Motion sensor in Closet fired with value ON at ten hours forty-nine minutes AM.',
#  'Motion sensor in Porch fired with value ON at ten hours forty-nine minutes AM.',
#  'Motion sensor in Porch fired with value OFF at ten hours forty-nine minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours forty-nine minutes AM.',
#  'Motion sensor in Closet fired with value OFF at ten hours forty-nine minutes AM.',
#  'Motion sensor in Basement fired with value OFF at ten hours forty-nine minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at ten hours forty-nine minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours forty-nine minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.0756262 at ten hours forty-nine minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.253324 at ten hours forty-nine minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours forty-nine minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.355474 at ten hours forty-nine minutes AM.',
#  'Motion sensor in Unknown fired with value ON at ten hours forty-nine minutes AM.',
#  'Motion sensor in Unknown fired with value OFF at ten hours forty-nine minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours forty-nine minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours forty-nine minutes AM.',
#  'Motion sensor in Porch fired with value ON at ten hours fifty-two minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-two minutes AM.',
#  'Motion sensor in Porch fired with value OFF at ten hours fifty-two minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at ten hours fifty-two minutes AM.',
#  'Motion sensor in Basement fired with value OFF at ten hours fifty-two minutes AM.',
#  'Motion sensor in Closet fired with value OFF at ten hours fifty-two minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-two minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-two minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-two minutes AM.',
#  'Motion sensor in Unknown fired with value ON at ten hours fifty-two minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-two minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-two minutes AM.',
#  'Unknown sensor in Living Room fired with value START_INSTRUCT at ten hours fifty-two minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-two minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-two minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-two minutes AM.',
#  'Motion sensor in Unknown fired with value OFF at ten hours fifty-two minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-two minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-three minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-three minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-three minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-three minutes AM.',
#  'Door sensor in Living Room fired with value OPEN at ten hours fifty-three minutes AM.',
#  'Unknown sensor in Living Room fired with value STOP_INSTRUCT at ten hours fifty-three minutes AM.',
#  'Item sensor in Kitchen fired with value ABSENT at ten hours fifty-three minutes AM.',
#  'Item sensor in Living Room fired with value ABSENT at ten hours fifty-three minutes AM.',
#  'Item sensor in Living Room fired with value PRESENT at ten hours fifty-three minutes AM.',
#  'Item sensor in Bathroom fired with value ABSENT at ten hours fifty-three minutes AM.',
#  'Door sensor in Living Room fired with value CLOSE at ten hours fifty-three minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-three minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.0421491 at ten hours fifty-three minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-three minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.155979 at ten hours fifty-three minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-three minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-four minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.223675 at ten hours fifty-four minutes AM.',
#  'Motion sensor in Stairs fired with value ON at eleven hours three minutes AM.',
#  'Motion sensor in Closet fired with value ON at eleven hours three minutes AM.',
#  'Motion sensor in Porch fired with value ON at eleven hours three minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours three minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at eleven hours three minutes AM.',
#  'Motion sensor in Basement fired with value OFF at eleven hours three minutes AM.',
#  'Motion sensor in Porch fired with value ON at eleven hours three minutes AM.',
#  'Motion sensor in Closet fired with value OFF at eleven hours three minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours three minutes AM.',
#  'Motion sensor in Porch fired with value OFF at eleven hours three minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours three minutes AM.',
#  'Door sensor in Living Room fired with value OPEN at eleven hours three minutes AM.',
#  'Item sensor in Hallway fired with value PRESENT at eleven hours three minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours three minutes AM.',
#  'Door sensor in Living Room fired with value CLOSE at eleven hours three minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours three minutes AM.',
#  'Motion sensor in Unknown fired with value ON at eleven hours three minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours three minutes AM.',
#  'Motion sensor in Unknown fired with value OFF at eleven hours three minutes AM.',
#  'Motion sensor in Unknown fired with value ON at eleven hours three minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours three minutes AM.',
#  'Motion sensor in Unknown fired with value OFF at eleven hours three minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.0418756 at eleven hours three minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours three minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.221097 at eleven hours four minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours four minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours four minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.0433991 at eleven hours four minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.136682 at eleven hours four minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.0331255 at eleven hours five minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.222855 at eleven hours five minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.369732 at eleven hours five minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.305942 at eleven hours five minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours five minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours five minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.227738 at eleven hours five minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.363248 at eleven hours six minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.304653 at eleven hours six minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.231136 at eleven hours six minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours six minutes AM.',
#  'Motion sensor in Unknown fired with value ON at eleven hours six minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours six minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours six minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours six minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours six minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours six minutes AM.',
#  'Motion sensor in Basement fired with value ON at eleven hours one minutes AM.',
#  'Motion sensor in Stairs fired with value ON at eleven hours one minutes AM.',
#  'Motion sensor in Closet fired with value ON at eleven hours one minutes AM.',
#  'Motion sensor in Porch fired with value ON at eleven hours one minutes AM.',
#  'Motion sensor in Basement fired with value OFF at eleven hours one minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours one minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at eleven hours one minutes AM.',
#  'Motion sensor in Closet fired with value OFF at eleven hours one minutes AM.',
#  'Motion sensor in Porch fired with value OFF at eleven hours one minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours one minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours one minutes AM.',
#  'Motion sensor in Unknown fired with value ON at eleven hours two minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours two minutes AM.',
#  'Motion sensor in Unknown fired with value OFF at eleven hours two minutes AM.',
#  'Motion sensor in Unknown fired with value ON at eleven hours two minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours two minutes AM.',
#  'Motion sensor in Unknown fired with value OFF at eleven hours two minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours two minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours two minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours two minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours two minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours two minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.0448444 at eleven hours two minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.138401 at eleven hours two minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.275981 at eleven hours three minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours three minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours three minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.22598 at eleven hours three minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.286176 at eleven hours three minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.213011 at eleven hours three minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.287153 at eleven hours four minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.222777 at eleven hours four minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.300005 at eleven hours four minutes AM.',
#  'Motion sensor in Unknown fired with value ON at eleven hours four minutes AM.',
#  'Motion sensor in Unknown fired with value ON at eleven hours four minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours four minutes AM.',
#  'Motion sensor in Unknown fired with value OFF at eleven hours four minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours four minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.244418 at eleven hours five minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.346529 at eleven hours five minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours five minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours five minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours six minutes AM.',
#  'Motion sensor in Unknown fired with value ON at eleven hours six minutes AM.',
#  'Motion sensor in Unknown fired with value OFF at eleven hours six minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours six minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours six minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours six minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours six minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.222347 at eleven hours six minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours six minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours six minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours six minutes AM.',
#  'Motion sensor in Unknown fired with value ON at eleven hours six minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours six minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours six minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours six minutes AM.',
#  'Door sensor in Living Room fired with value OPEN at eleven hours six minutes AM.',
#  'Motion sensor in Unknown fired with value OFF at eleven hours six minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours six minutes AM.',
#  'Item sensor in Kitchen fired with value PRESENT at eleven hours six minutes AM.',
#  'Item sensor in Living Room fired with value PRESENT at eleven hours six minutes AM.',
#  'Item sensor in Hallway fired with value PRESENT at eleven hours six minutes AM.',
#  'Door sensor in Living Room fired with value CLOSE at eleven hours seven minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours thirty-one minutes AM.',
#  'Motion sensor in Unknown fired with value ON at eleven hours thirty-one minutes AM.',
#  'Motion sensor in Unknown fired with value OFF at eleven hours thirty-one minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours thirty-one minutes AM.',
#  'Door sensor in Living Room fired with value OPEN at eleven hours thirty-one minutes AM.',
#  'Unknown sensor in Unknown fired with value 2.84247 at eleven hours thirty-one minutes AM.',
#  'Item sensor in Living Room fired with value ABSENT at eleven hours thirty-one minutes AM.',
#  'Unknown sensor in Unknown fired with value 2.97669 at eleven hours thirty-one minutes AM.',
#  'Item sensor in Kitchen fired with value ABSENT at eleven hours thirty-one minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.06669 at eleven hours thirty-one minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.12919 at eleven hours thirty-one minutes AM.',
#  'Item sensor in Garage fired with value ABSENT at eleven hours thirty-one minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.18661 at eleven hours thirty-one minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours thirty-one minutes AM.',
#  'Item sensor in Bathroom fired with value ABSENT at eleven hours thirty-one minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours thirty-one minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours thirty-one minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.24005 at eleven hours thirty-one minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours thirty-one minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours thirty-one minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours thirty-two minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.0388678 at eleven hours thirty-two minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.15638 at eleven hours thirty-two minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.218988 at eleven hours thirty-two minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.0855091 at eleven hours thirty-two minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours thirty-two minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours thirty-two minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.07966 at eleven hours thirty-two minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours thirty-two minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours thirty-two minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours thirty-two minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours thirty-two minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours thirty-two minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours thirty-two minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours thirty-two minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours thirty-three minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.02809 at eleven hours thirty-three minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.12677 at eleven hours thirty-three minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours thirty-three minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.21646 at eleven hours thirty-three minutes AM.',
#  'Motion sensor in Unknown fired with value ON at eleven hours thirty-three minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours thirty-three minutes AM.',
#  'Motion sensor in Unknown fired with value OFF at eleven hours thirty-three minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours thirty-three minutes AM.',
#  'Item sensor in Kitchen fired with value PRESENT at eleven hours thirty-four minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours thirty-four minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours thirty-four minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.29114 at eleven hours thirty-four minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.34583 at eleven hours thirty-four minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.21981 at eleven hours thirty-four minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.11184 at eleven hours thirty-four minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.02481 at eleven hours thirty-four minutes AM.',
#  'Unknown sensor in Unknown fired with value 2.9427 at eleven hours thirty-five minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.01739 at eleven hours thirty-five minutes AM.',
#  'Item sensor in Bedroom 1 fired with value ABSENT at eleven hours thirty-five minutes AM.',
#  'Unknown sensor in Unknown fired with value 2.96481 at eleven hours thirty-six minutes AM.',
#  'Unknown sensor in Unknown fired with value 2.88004 at eleven hours thirty-six minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours thirty-six minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours thirty-six minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours thirty-six minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours thirty-six minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours thirty-six minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours thirty-six minutes AM.',
#  'Item sensor in Bedroom 2 fired with value ABSENT at eleven hours thirty-seven minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours thirty-eight minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours thirty-eight minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours thirty-eight minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours thirty-nine minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.0345708 at eleven hours thirty-nine minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.452858 at eleven hours thirty-nine minutes AM.',
#  'Motion sensor in Unknown fired with value ON at eleven hours thirty-nine minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.185393 at eleven hours thirty-nine minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours thirty-nine minutes AM.',
#  'Motion sensor in Unknown fired with value OFF at eleven hours thirty-nine minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.0996109 at eleven hours thirty-nine minutes AM.',
#  'Item sensor in Hallway fired with value ABSENT at eleven hours thirty-nine minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours thirty-nine minutes AM.',
#  'Motion sensor in Porch fired with value ON at eleven hours thirty-nine minutes AM.',
#  'Motion sensor in Closet fired with value ON at eleven hours thirty-nine minutes AM.',
#  'Motion sensor in Stairs fired with value ON at eleven hours thirty-nine minutes AM.',
#  'Motion sensor in Basement fired with value ON at eleven hours thirty-nine minutes AM.',
#  'Motion sensor in Porch fired with value OFF at eleven hours thirty-nine minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at eleven hours thirty-nine minutes AM.',
#  'Motion sensor in Closet fired with value OFF at eleven hours thirty-nine minutes AM.',
#  'Motion sensor in Basement fired with value OFF at eleven hours thirty-nine minutes AM.',
#  'Motion sensor in Basement fired with value ON at eleven hours thirty-nine minutes AM.',
#  'Motion sensor in Basement fired with value OFF at eleven hours thirty-nine minutes AM.',
#  'Motion sensor in Basement fired with value ON at eleven hours thirty-nine minutes AM.',
#  'Motion sensor in Basement fired with value OFF at eleven hours thirty-nine minutes AM.',
#  'Motion sensor in Basement fired with value ON at eleven hours thirty-nine minutes AM.',
#  'Motion sensor in Basement fired with value OFF at eleven hours thirty-nine minutes AM.',
#  'Motion sensor in Basement fired with value ON at eleven hours forty minutes AM.',
#  'Motion sensor in Basement fired with value OFF at eleven hours forty minutes AM.',
#  'Motion sensor in Basement fired with value ON at eleven hours forty minutes AM.',
#  'Motion sensor in Basement fired with value OFF at eleven hours forty minutes AM.',
#  'Motion sensor in Basement fired with value ON at eleven hours forty minutes AM.',
#  'Motion sensor in Basement fired with value OFF at eleven hours forty minutes AM.',
#  'Motion sensor in Basement fired with value ON at eleven hours forty minutes AM.',
#  'Motion sensor in Basement fired with value OFF at eleven hours forty minutes AM.',
#  'Motion sensor in Basement fired with value ON at eleven hours forty minutes AM.',
#  'Motion sensor in Basement fired with value ON at eleven hours forty minutes AM.',
#  'Motion sensor in Basement fired with value OFF at eleven hours forty minutes AM.',
#  'Motion sensor in Basement fired with value ON at eleven hours forty minutes AM.',
#  'Motion sensor in Basement fired with value OFF at eleven hours forty minutes AM.',
#  'Motion sensor in Basement fired with value ON at eleven hours forty minutes AM.',
#  'Motion sensor in Basement fired with value OFF at eleven hours forty minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours seven minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.0540633 at eleven hours seven minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours seven minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.190003 at eleven hours seven minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.0573837 at eleven hours seven minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.246918 at eleven hours seven minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.398522 at eleven hours seven minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.213831 at eleven hours seven minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours seven minutes AM.',
#  'Door sensor in Living Room fired with value OPEN at eleven hours seven minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours seven minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours seven minutes AM.',
#  'Item sensor in Hallway fired with value ABSENT at eleven hours seven minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.114064 at eleven hours seven minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.198128 at eleven hours seven minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours seven minutes AM.',
#  'Door sensor in Living Room fired with value CLOSE at eleven hours seven minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours seven minutes AM.',
#  'Motion sensor in Porch fired with value ON at eleven hours seven minutes AM.',
#  'Motion sensor in Closet fired with value ON at eleven hours seven minutes AM.',
#  'Motion sensor in Stairs fired with value ON at eleven hours seven minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours seven minutes AM.',
#  'Motion sensor in Basement fired with value ON at eleven hours seven minutes AM.',
#  'Motion sensor in Closet fired with value OFF at eleven hours seven minutes AM.',
#  'Motion sensor in Porch fired with value OFF at eleven hours seven minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at eleven hours eight minutes AM.',
#  'Motion sensor in Stairs fired with value ON at eleven hours eight minutes AM.',
#  'Motion sensor in Basement fired with value OFF at eleven hours eight minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at eleven hours eight minutes AM.',
#  'Motion sensor in Stairs fired with value ON at eleven hours eight minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at eleven hours eight minutes AM.',
#  'Motion sensor in Stairs fired with value ON at eleven hours eight minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at eleven hours eight minutes AM.',
#  'Motion sensor in Stairs fired with value ON at eleven hours eight minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at eleven hours eight minutes AM.',
#  'Motion sensor in Stairs fired with value ON at eleven hours nine minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at eleven hours nine minutes AM.',
#  'Motion sensor in Stairs fired with value ON at eleven hours nine minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at eleven hours nine minutes AM.',
#  'Motion sensor in Stairs fired with value ON at eleven hours nine minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at eleven hours nine minutes AM.',
#  'Motion sensor in Stairs fired with value ON at eleven hours nine minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at eleven hours nine minutes AM.',
#  'Motion sensor in Stairs fired with value ON at eleven hours nine minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at eleven hours nine minutes AM.',
#  'Motion sensor in Stairs fired with value ON at eleven hours nine minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at eleven hours nine minutes AM.',
#  'Motion sensor in Stairs fired with value ON at eleven hours nine minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at eleven hours nine minutes AM.',
#  'Motion sensor in Stairs fired with value ON at eleven hours nine minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at eleven hours nine minutes AM.',
#  'Motion sensor in Stairs fired with value ON at eleven hours ten minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at eleven hours ten minutes AM.',
#  'Motion sensor in Stairs fired with value ON at eleven hours eleven minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at eleven hours eleven minutes AM.',
#  'Motion sensor in Stairs fired with value ON at eleven hours eleven minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at eleven hours eleven minutes AM.',
#  'Motion sensor in Stairs fired with value ON at eleven hours eleven minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at eleven hours eleven minutes AM.',
#  'Motion sensor in Stairs fired with value ON at eleven hours twelve minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at eleven hours twelve minutes AM.',
#  'Motion sensor in Stairs fired with value ON at eleven hours twelve minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at eleven hours twelve minutes AM.',
#  'Motion sensor in Basement fired with value ON at eleven hours thirteen minutes AM.',
#  'Motion sensor in Stairs fired with value ON at eleven hours thirteen minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at eleven hours thirteen minutes AM.',
#  'Motion sensor in Basement fired with value OFF at eleven hours thirteen minutes AM.',
#  'Motion sensor in Stairs fired with value ON at eleven hours thirteen minutes AM.',
#  'Motion sensor in Stairs fired with value OFF at eleven hours thirteen minutes AM.',
#  'Motion sensor in Basement fired with value ON at eleven hours thirteen minutes AM.',
#  'Motion sensor in Basement fired with value OFF at eleven hours thirteen minutes AM.',
#  'Motion sensor in Basement fired with value ON at eleven hours thirteen minutes AM.',
#  'Motion sensor in Basement fired with value OFF at eleven hours thirteen minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-seven minutes AM.',
#  'Door sensor in Living Room fired with value OPEN at ten hours fifty-seven minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-eight minutes AM.',
#  'Item sensor in Garage fired with value ABSENT at ten hours fifty-eight minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-eight minutes AM.',
#  'Item sensor in Kitchen fired with value ABSENT at ten hours fifty-eight minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-eight minutes AM.',
#  'Item sensor in Bathroom fired with value ABSENT at ten hours fifty-eight minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-eight minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-eight minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-eight minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-eight minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.0369537 at ten hours fifty-eight minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.138479 at ten hours fifty-eight minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.0375787 at ten hours fifty-eight minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-eight minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.196097 at ten hours fifty-eight minutes AM.',
#  'Door sensor in Living Room fired with value CLOSE at ten hours fifty-eight minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-eight minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-eight minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-eight minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-eight minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-eight minutes AM.',
#  'Unknown sensor in Unknown fired with value 2.82895 at ten hours fifty-nine minutes AM.',
#  'Unknown sensor in Unknown fired with value 2.93879 at ten hours fifty-nine minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-nine minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.01434 at ten hours fifty-nine minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.09442 at ten hours fifty-nine minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-nine minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-nine minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.16497 at ten hours fifty-nine minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-nine minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-nine minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-nine minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-nine minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.24278 at ten hours fifty-nine minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-nine minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-nine minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-nine minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-nine minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.30005 at ten hours fifty-nine minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-nine minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-nine minutes AM.',
#  'Door sensor in Living Room fired with value OPEN at ten hours fifty-nine minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-nine minutes AM.',
#  'Item sensor in Kitchen fired with value PRESENT at ten hours fifty-nine minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.24177 at eleven hours zero minutes AM.',
#  'Item sensor in Living Room fired with value ABSENT at eleven hours zero minutes AM.',
#  'Item sensor in Bedroom 1 fired with value ABSENT at eleven hours zero minutes AM.',
#  'Door sensor in Living Room fired with value CLOSE at eleven hours zero minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours zero minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours zero minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours zero minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours zero minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours zero minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours zero minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours one minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours one minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours one minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.19106 at eleven hours one minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.13489 at eleven hours one minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours one minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours one minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours one minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours one minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.1945 at eleven hours one minutes AM.',
#  'Door sensor in Living Room fired with value OPEN at eleven hours one minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours one minutes AM.',
#  'Item sensor in Bedroom 2 fired with value ABSENT at eleven hours one minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours one minutes AM.',
#  'Item sensor in Living Room fired with value PRESENT at eleven hours one minutes AM.',
#  'Door sensor in Living Room fired with value CLOSE at eleven hours one minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours one minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.038399 at eleven hours one minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours one minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.293012 at eleven hours one minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours one minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.242074 at eleven hours one minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours one minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.14434 at eleven hours two minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.19552 at eleven hours two minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.12434 at eleven hours three minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.02919 at eleven hours three minutes AM.',
#  'Unknown sensor in Unknown fired with value 2.97715 at eleven hours three minutes AM.',
#  'Unknown sensor in Unknown fired with value 2.89708 at eleven hours three minutes AM.',
#  'Unknown sensor in Unknown fired with value 2.83879 at eleven hours four minutes AM.',
#  'Unknown sensor in Unknown fired with value 2.90465 at eleven hours four minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours five minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours five minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.0421491 at eleven hours five minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.169065 at eleven hours five minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.0414459 at eleven hours six minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.301801 at eleven hours six minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.417584 at eleven hours six minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.486921 at eleven hours six minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours six minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours six minutes AM.',
#  'Motion sensor in Attic fired with value ON at eleven hours six minutes AM.',
#  'Motion sensor in Attic fired with value OFF at eleven hours six minutes AM.',
#  'Motion sensor in Stairs fired with value ON at one hours one minutes PM.',
#  'Motion sensor in Basement fired with value OFF at one hours one minutes PM.',
#  'Motion sensor in Stairs fired with value ON at one hours one minutes PM.',
#  'Motion sensor in Basement fired with value ON at one hours two minutes PM.',
#  'Motion sensor in Stairs fired with value OFF at one hours two minutes PM.',
#  'Motion sensor in Basement fired with value OFF at one hours two minutes PM.',
#  'Motion sensor in Stairs fired with value ON at one hours two minutes PM.',
#  'Motion sensor in Basement fired with value ON at one hours two minutes PM.',
#  'Motion sensor in Basement fired with value OFF at one hours two minutes PM.',
#  'Motion sensor in Closet fired with value ON at one hours two minutes PM.',
#  'Motion sensor in Porch fired with value ON at one hours two minutes PM.',
#  'Motion sensor in Attic fired with value ON at one hours two minutes PM.',
#  'Motion sensor in Closet fired with value OFF at one hours two minutes PM.',
#  'Motion sensor in Stairs fired with value OFF at one hours two minutes PM.',
#  'Motion sensor in Porch fired with value OFF at one hours two minutes PM.',
#  'Motion sensor in Attic fired with value OFF at one hours two minutes PM.',
#  'Motion sensor in Attic fired with value ON at one hours two minutes PM.',
#  'Motion sensor in Attic fired with value OFF at one hours two minutes PM.',
#  'Motion sensor in Attic fired with value ON at one hours two minutes PM.',
#  'Door sensor in Living Room fired with value OPEN at one hours two minutes PM.',
#  'Motion sensor in Attic fired with value OFF at one hours two minutes PM.',
#  'Item sensor in Bedroom 2 fired with value PRESENT at one hours two minutes PM.',
#  'Item sensor in Bedroom 1 fired with value PRESENT at one hours two minutes PM.',
#  'Item sensor in Hallway fired with value PRESENT at one hours two minutes PM.',
#  'Motion sensor in Attic fired with value ON at one hours two minutes PM.',
#  'Door sensor in Living Room fired with value CLOSE at one hours two minutes PM.',
#  'Motion sensor in Unknown fired with value ON at one hours three minutes PM.',
#  'Motion sensor in Attic fired with value OFF at one hours three minutes PM.',
#  'Motion sensor in Unknown fired with value OFF at one hours three minutes PM.',
#  'Motion sensor in Unknown fired with value ON at one hours three minutes PM.',
#  'Motion sensor in Attic fired with value ON at one hours three minutes PM.',
#  'Motion sensor in Unknown fired with value OFF at one hours three minutes PM.',
#  'Motion sensor in Attic fired with value OFF at one hours three minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.0676182 at one hours three minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.277075 at one hours three minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.434733 at one hours four minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.344849 at one hours four minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.0508211 at one hours five minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.419811 at one hours five minutes PM.',
#  'Motion sensor in Unknown fired with value ON at one hours six minutes PM.',
#  'Motion sensor in Unknown fired with value OFF at one hours six minutes PM.',
#  'Motion sensor in Attic fired with value ON at one hours six minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.476374 at one hours six minutes PM.',
#  'Motion sensor in Unknown fired with value ON at one hours six minutes PM.',
#  'Motion sensor in Attic fired with value OFF at one hours six minutes PM.',
#  'Motion sensor in Unknown fired with value OFF at one hours six minutes PM.',
#  'Motion sensor in Unknown fired with value ON at one hours six minutes PM.',
#  'Motion sensor in Attic fired with value ON at one hours six minutes PM.',
#  'Motion sensor in Unknown fired with value ON at one hours six minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.0590243 at one hours six minutes PM.',
#  'Motion sensor in Unknown fired with value OFF at one hours six minutes PM.',
#  'Motion sensor in Attic fired with value OFF at one hours six minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.364185 at one hours six minutes PM.',
#  'Motion sensor in Attic fired with value ON at one hours seven minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.486101 at one hours seven minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.103908 at one hours seven minutes PM.',
#  'Motion sensor in Unknown fired with value ON at one hours seven minutes PM.',
#  'Motion sensor in Unknown fired with value OFF at one hours seven minutes PM.',
#  'Motion sensor in Stairs fired with value OFF at two hours nine minutes PM.',
#  'Motion sensor in Stairs fired with value ON at two hours nine minutes PM.',
#  'Motion sensor in Basement fired with value ON at two hours nine minutes PM.',
#  'Motion sensor in Stairs fired with value OFF at two hours nine minutes PM.',
#  'Motion sensor in Basement fired with value OFF at two hours nine minutes PM.',
#  'Motion sensor in Stairs fired with value ON at two hours nine minutes PM.',
#  'Motion sensor in Basement fired with value ON at two hours nine minutes PM.',
#  'Motion sensor in Closet fired with value ON at two hours nine minutes PM.',
#  'Motion sensor in Porch fired with value ON at two hours nine minutes PM.',
#  'Motion sensor in Attic fired with value ON at two hours nine minutes PM.',
#  'Motion sensor in Basement fired with value OFF at two hours nine minutes PM.',
#  'Motion sensor in Stairs fired with value OFF at two hours nine minutes PM.',
#  'Motion sensor in Closet fired with value OFF at two hours nine minutes PM.',
#  'Motion sensor in Porch fired with value OFF at two hours nine minutes PM.',
#  'Motion sensor in Attic fired with value OFF at two hours nine minutes PM.',
#  'Motion sensor in Attic fired with value ON at two hours nine minutes PM.',
#  'Door sensor in Living Room fired with value OPEN at two hours nine minutes PM.',
#  'Item sensor in Hallway fired with value PRESENT at two hours nine minutes PM.',
#  'Door sensor in Living Room fired with value CLOSE at two hours nine minutes PM.',
#  'Motion sensor in Attic fired with value OFF at two hours nine minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.0342583 at two hours nine minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.297114 at two hours nine minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.458054 at two hours nine minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.511336 at two hours nine minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.47739 at two hours nine minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.501844 at two hours nine minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.467195 at two hours nine minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.488523 at two hours nine minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.510398 at two hours ten minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.486765 at two hours ten minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.514969 at two hours ten minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.46571 at two hours ten minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.489617 at two hours ten minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.509891 at two hours ten minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.459616 at two hours ten minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.483953 at two hours ten minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.504383 at two hours ten minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.47989 at two hours eleven minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.452116 at two hours eleven minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.484343 at two hours eleven minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.511141 at two hours eleven minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.488406 at two hours eleven minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.533485 at two hours eleven minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.491531 at two hours eleven minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.466726 at two hours eleven minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.492742 at two hours eleven minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.515711 at two hours eleven minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.47782 at two hours eleven minutes PM.',
#  'Motion sensor in Unknown fired with value ON at two hours eleven minutes PM.',
#  'Motion sensor in Unknown fired with value OFF at two hours eleven minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.455554 at two hours eleven minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.491257 at two hours twelve minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.530594 at two hours twelve minutes PM.',
#  'Motion sensor in Unknown fired with value ON at two hours twelve minutes PM.',
#  'Motion sensor in Unknown fired with value OFF at two hours twelve minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.49032 at two hours twelve minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.515438 at two hours twelve minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.491375 at two hours twelve minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.455671 at two hours twelve minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.499304 at two hours twelve minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.376099 at two hours twelve minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.0567196 at two hours twelve minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.295669 at two hours twelve minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.0770324 at two hours twelve minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.0369146 at two hours twelve minutes PM.',
# ...
#  'Unknown sensor in Unknown fired with value 3.00348 at ten hours fifty-four minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.07622 at ten hours fifty-four minutes AM.',
#  'Door sensor in Living Room fired with value CLOSE at ten hours fifty-four minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-four minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.13911 at ten hours fifty-four minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-four minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.22302 at ten hours fifty-four minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.2795 at ten hours fifty-five minutes AM.',
#  'Door sensor in Living Room fired with value OPEN at ten hours fifty-five minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-five minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-five minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-five minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-five minutes AM.',
#  'Door sensor in Living Room fired with value CLOSE at ten hours fifty-five minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-five minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-five minutes AM.',
#  'Door sensor in Living Room fired with value OPEN at ten hours fifty-five minutes AM.',
#  'Door sensor in Living Room fired with value CLOSE at ten hours fifty-five minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-five minutes AM.',
#  'Door sensor in Living Room fired with value OPEN at ten hours fifty-six minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-six minutes AM.',
#  'Item sensor in Bedroom 1 fired with value ABSENT at ten hours fifty-six minutes AM.',
#  'Item sensor in Bedroom 1 fired with value PRESENT at ten hours fifty-six minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-six minutes AM.',
#  'Item sensor in Bedroom 2 fired with value ABSENT at ten hours fifty-six minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-six minutes AM.',
#  'Item sensor in Living Room fired with value PRESENT at ten hours fifty-six minutes AM.',
#  'Item sensor in Kitchen fired with value PRESENT at ten hours fifty-six minutes AM.',
#  'Door sensor in Living Room fired with value CLOSE at ten hours fifty-six minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-six minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-six minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-six minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-six minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-six minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-six minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-seven minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-seven minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-seven minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-seven minutes AM.',
#  'Door sensor in Living Room fired with value OPEN at ten hours fifty-seven minutes AM.',
#  'Door sensor in Living Room fired with value CLOSE at ten hours fifty-seven minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.32966 at ten hours fifty-seven minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-seven minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.23286 at ten hours fifty-seven minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-seven minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-seven minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.12372 at ten hours fifty-seven minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-seven minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-seven minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-seven minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.04739 at ten hours fifty-seven minutes AM.',
#  'Unknown sensor in Unknown fired with value 2.97989 at ten hours fifty-eight minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-eight minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.04427 at ten hours fifty-eight minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-eight minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-eight minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-eight minutes AM.',
#  'Unknown sensor in Unknown fired with value 2.98614 at ten hours fifty-eight minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-nine minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-nine minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-nine minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-nine minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.04692 at ten hours fifty-nine minutes AM.',
#  'Unknown sensor in Unknown fired with value 2.98153 at ten hours fifty-nine minutes AM.',
#  'Unknown sensor in Unknown fired with value 2.90926 at ten hours fifty-nine minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty minutes AM.',
#  'Door sensor in Living Room fired with value OPEN at ten hours fifty minutes AM.',
#  'Item sensor in Kitchen fired with value ABSENT at ten hours fifty minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty minutes AM.',
#  'Item sensor in Living Room fired with value ABSENT at ten hours fifty minutes AM.',
#  'Item sensor in Bedroom 2 fired with value ABSENT at ten hours fifty minutes AM.',
#  'Item sensor in Bathroom fired with value ABSENT at ten hours fifty minutes AM.',
#  'Item sensor in Bedroom 1 fired with value ABSENT at ten hours fifty minutes AM.',
#  'Item sensor in Garage fired with value ABSENT at ten hours fifty-one minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-one minutes AM.',
#  'Door sensor in Living Room fired with value CLOSE at ten hours fifty-one minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-one minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-one minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-one minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.053243 at ten hours fifty-one minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.293442 at ten hours fifty-one minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-one minutes AM.',
#  'Unknown sensor in Unknown fired with value 0.207152 at ten hours fifty-one minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-one minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-one minutes AM.',
#  'Unknown sensor in Unknown fired with value 2.80637 at ten hours fifty-one minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-one minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-one minutes AM.',
#  'Unknown sensor in Unknown fired with value 2.96583 at ten hours fifty-one minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.07091 at ten hours fifty-one minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.12466 at ten hours fifty-one minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-one minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-two minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.22771 at ten hours fifty-two minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-two minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-two minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-two minutes AM.',
#  'Motion sensor in Unknown fired with value ON at ten hours fifty-two minutes AM.',
#  'Motion sensor in Unknown fired with value OFF at ten hours fifty-two minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.29622 at ten hours fifty-two minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.16458 at ten hours fifty-two minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-two minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.21747 at ten hours fifty-two minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.16005 at ten hours fifty-two minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-two minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-two minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-two minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-three minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.10606 at ten hours fifty-three minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.16005 at ten hours fifty-three minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.23411 at ten hours fifty-three minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-four minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-four minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-four minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-four minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-four minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-four minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-four minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-four minutes AM.',
#  'Motion sensor in Unknown fired with value ON at ten hours fifty-four minutes AM.',
#  'Motion sensor in Unknown fired with value OFF at ten hours fifty-four minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-four minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.2956 at ten hours fifty-five minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.13974 at ten hours fifty-five minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.05669 at ten hours fifty-five minutes AM.',
#  'Unknown sensor in Unknown fired with value 2.99278 at ten hours fifty-five minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-five minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-five minutes AM.',
#  'Unknown sensor in Unknown fired with value 2.9134 at ten hours fifty-five minutes AM.',
#  'Unknown sensor in Unknown fired with value 2.98278 at ten hours fifty-five minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-six minutes AM.',
#  'Unknown sensor in Unknown fired with value 3.04427 at ten hours fifty-six minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-six minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-six minutes AM.',
#  'Unknown sensor in Unknown fired with value 2.98528 at ten hours fifty-six minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-seven minutes AM.',
#  'Unknown sensor in Unknown fired with value 2.90215 at ten hours fifty-seven minutes AM.',
#  'Motion sensor in Attic fired with value OFF at ten hours fifty-seven minutes AM.',
#  'Motion sensor in Attic fired with value ON at ten hours fifty-seven minutes AM.',
#  'Motion sensor in Attic fired with value ON at twelve hours fifty minutes PM.',
#  'Item sensor in Garage fired with value ABSENT at twelve hours fifty minutes PM.',
#  'Door sensor in Living Room fired with value OPEN at twelve hours fifty-one minutes PM.',
#  'Item sensor in Kitchen fired with value ABSENT at twelve hours fifty-one minutes PM.',
#  'Item sensor in Bedroom 1 fired with value ABSENT at twelve hours fifty-one minutes PM.',
#  'Item sensor in Living Room fired with value ABSENT at twelve hours fifty-one minutes PM.',
#  'Motion sensor in Attic fired with value ON at twelve hours fifty-one minutes PM.',
#  'Item sensor in Bedroom 2 fired with value ABSENT at twelve hours fifty-one minutes PM.',
#  'Item sensor in Bathroom fired with value ABSENT at twelve hours fifty-one minutes PM.',
#  'Door sensor in Living Room fired with value CLOSE at twelve hours fifty-one minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.0338677 at twelve hours fifty-one minutes PM.',
#  'Motion sensor in Attic fired with value OFF at twelve hours fifty-one minutes PM.',
#  'Unknown sensor in Unknown fired with value 0.129533 at twelve hours fifty-one minutes PM.',
#  'Motion sensor in Attic fired with value ON at twelve hours fifty-one minutes PM.',
#  'Unknown sensor in Unknown fired with value 2.81965 at twelve hours fifty-one minutes PM.',
#  'Unknown sensor in Unknown fired with value 2.88004 at twelve hours fifty-one minutes PM.',
#  'Motion sensor in Attic fired with value OFF at twelve hours fifty-one minutes PM.',
#  'Unknown sensor in Unknown fired with value 2.99841 at twelve hours fifty-one minutes PM.',
#  'Motion sensor in Attic fired with value ON at twelve hours fifty-one minutes PM.',
#  'Unknown sensor in Unknown fired with value 3.07684 at twelve hours fifty-one minutes PM.',
#  'Unknown sensor in Unknown fired with value 3.14442 at twelve hours fifty-two minutes PM.',
#  'Motion sensor in Attic fired with value OFF at twelve hours fifty-two minutes PM.',
#  'Unknown sensor in Unknown fired with value 3.22653 at twelve hours fifty-two minutes PM.',
#  'Motion sensor in Attic fired with value ON at twelve hours fifty-two minutes PM.',
#  'Unknown sensor in Living Room fired with value STOP_INSTRUCT at twelve hours fifty-two minutes PM.',
#  'Motion sensor in Attic fired with value OFF at twelve hours fifty-two minutes PM.',
#  'Motion sensor in Attic fired with value ON at twelve hours fifty-two minutes PM.',
#  'Motion sensor in Attic fired with value OFF at twelve hours fifty-two minutes PM.',
#  'Motion sensor in Attic fired with value ON at twelve hours fifty-two minutes PM.',
#  'Motion sensor in Attic fired with value OFF at twelve hours fifty-two minutes PM.',
#  'Motion sensor in Attic fired with value ON at twelve hours fifty-three minutes PM.',
#  'Door sensor in Living Room fired with value OPEN at twelve hours fifty-three minutes PM.',
#  'Door sensor in Living Room fired with value CLOSE at twelve hours fifty-three minutes PM.',
#  'Unknown sensor in Unknown fired with value 3.28802 at twelve hours fifty-three minutes PM.',
#  'Motion sensor in Attic fired with value OFF at twelve hours fifty-three minutes PM.',
#  'Motion sensor in Porch fired with value ON at twelve hours fifty-three minutes PM.',
#  'Motion sensor in Porch fired with value OFF at twelve hours fifty-three minutes PM.',
#  'Motion sensor in Attic fired with value ON at twelve hours fifty-three minutes PM.',
#  'Motion sensor in Attic fired with value OFF at twelve hours fifty-three minutes PM.',
#  'Motion sensor in Attic fired with value ON at twelve hours fifty-three minutes PM.',
#  'Motion sensor in Attic fired with value OFF at twelve hours fifty-three minutes PM.',
#  'Motion sensor in Attic fired with value ON at twelve hours fifty-four minutes PM.',
#  'Motion sensor in Attic fired with value OFF at twelve hours fifty-four minutes PM.',
#  'Motion sensor in Attic fired with value ON at twelve hours fifty-four minutes PM.',
#  'Motion sensor in Attic fired with value OFF at twelve hours fifty-four minutes PM.',
#  ...]

# %%
def generate_temporal_tdost(sensor_data):
    descriptions = []
    prev_time = None
    for index, row in sensor_data.iterrows():
        curr_sensor_type = get_sensor_type(row['Sensor_ID'])
        curr_sensor_location = get_sensor_location(row['Sensor_ID'])
        curr_sensor_time_words = timestamp_to_words(row['Timestamp'])
        curr_sensor_value = row['State']
        current_time = pd.to_datetime(row['Timestamp'])

        if prev_time is not None:
            time_diff = round((current_time - prev_time).total_seconds(), 2)

            # Consider it a new 'stream' if time difference is negative, or more than 5 minutes
            if time_diff < 0 or time_diff > 300:
                description = f"{curr_sensor_type} sensor in the {curr_sensor_location} fired with value {curr_sensor_value} at {curr_sensor_time_words}."
            else:
                description = f"After {time_diff} seconds, {curr_sensor_type} sensor in the {curr_sensor_location} fired with value {curr_sensor_value}."
        else:
            description = f"{curr_sensor_type} sensor in the {curr_sensor_location} fired with value {curr_sensor_value} at {curr_sensor_time_words}."

        descriptions.append(description)
        prev_time = current_time
    return descriptions

# casas_data['TDOST_Temporal'] = generate_temporal_tdost(casas_data)
# casas_data['TDOST_Temporal']
generate_temporal_tdost(casas_data)
# Out:
# ['Motion sensor in the Basement fired with value ON at ten hours forty-nine minutes AM.',
#  'After 4.71 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 1.45 seconds, Motion sensor in the Closet fired with value ON.',
#  'After 0.86 seconds, Motion sensor in the Porch fired with value ON.',
#  'After 1.64 seconds, Motion sensor in the Porch fired with value OFF.',
#  'After 0.25 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.03 seconds, Motion sensor in the Closet fired with value OFF.',
#  'After 0.14 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 0.0 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 4.17 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 14.92 seconds, Unknown sensor in the Unknown fired with value 0.0756262.',
#  'After 2.32 seconds, Unknown sensor in the Unknown fired with value 0.253324.',
#  'After 7.51 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.5 seconds, Unknown sensor in the Unknown fired with value 0.355474.',
#  'After 8.66 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 0.99 seconds, Motion sensor in the Unknown fired with value OFF.',
#  'After 1.06 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.14 seconds, Motion sensor in the Attic fired with value OFF.',
#  'Motion sensor in the Porch fired with value ON at ten hours fifty-two minutes AM.',
#  'After 0.84 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.61 seconds, Motion sensor in the Porch fired with value OFF.',
#  'After 0.6 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 0.98 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 0.0 seconds, Motion sensor in the Closet fired with value OFF.',
#  'After 1.04 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 19.34 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 3.65 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.86 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 3.58 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.49 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.53 seconds, Unknown sensor in the Living Room fired with value START_INSTRUCT.',
#  'After 0.39 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.13 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 2.06 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.07 seconds, Motion sensor in the Unknown fired with value OFF.',
#  'After 0.14 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.66 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 18.76 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 10.72 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 9.01 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.76 seconds, Door sensor in the Living Room fired with value OPEN.',
#  'After 0.29 seconds, Unknown sensor in the Living Room fired with value STOP_INSTRUCT.',
#  'After 2.51 seconds, Item sensor in the Kitchen fired with value ABSENT.',
#  'After 0.47 seconds, Item sensor in the Living Room fired with value ABSENT.',
#  'After 0.28 seconds, Item sensor in the Living Room fired with value PRESENT.',
#  'After 0.72 seconds, Item sensor in the Bathroom fired with value ABSENT.',
#  'After 2.91 seconds, Door sensor in the Living Room fired with value CLOSE.',
#  'After 3.57 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.66 seconds, Unknown sensor in the Unknown fired with value 0.0421491.',
#  'After 2.61 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.39 seconds, Unknown sensor in the Unknown fired with value 0.155979.',
#  'After 0.74 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 5.14 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.13 seconds, Unknown sensor in the Unknown fired with value 0.223675.',
#  'Motion sensor in the Stairs fired with value ON at eleven hours three minutes AM.',
#  'After 1.41 seconds, Motion sensor in the Closet fired with value ON.',
#  'After 0.35 seconds, Motion sensor in the Porch fired with value ON.',
#  'After 1.56 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.08 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 0.31 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 1.56 seconds, Motion sensor in the Porch fired with value ON.',
#  'After 0.7 seconds, Motion sensor in the Closet fired with value OFF.',
#  'After 0.15 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.26 seconds, Motion sensor in the Porch fired with value OFF.',
#  'After 2.66 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.42 seconds, Door sensor in the Living Room fired with value OPEN.',
#  'After 2.01 seconds, Item sensor in the Hallway fired with value PRESENT.',
#  'After 1.57 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.62 seconds, Door sensor in the Living Room fired with value CLOSE.',
#  'After 0.0 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 6.96 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 5.39 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.29 seconds, Motion sensor in the Unknown fired with value OFF.',
#  'After 1.38 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 1.33 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.45 seconds, Motion sensor in the Unknown fired with value OFF.',
#  'After 0.97 seconds, Unknown sensor in the Unknown fired with value 0.0418756.',
#  'After 0.22 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 2.71 seconds, Unknown sensor in the Unknown fired with value 0.221097.',
#  'After 49.78 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 3.74 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.43 seconds, Unknown sensor in the Unknown fired with value 0.0433991.',
#  'After 3.78 seconds, Unknown sensor in the Unknown fired with value 0.136682.',
#  'After 11.24 seconds, Unknown sensor in the Unknown fired with value 0.0331255.',
#  'After 8.97 seconds, Unknown sensor in the Unknown fired with value 0.222855.',
#  'After 6.01 seconds, Unknown sensor in the Unknown fired with value 0.369732.',
#  'After 5.95 seconds, Unknown sensor in the Unknown fired with value 0.305942.',
#  'After 0.66 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.11 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 4.33 seconds, Unknown sensor in the Unknown fired with value 0.227738.',
#  'After 39.59 seconds, Unknown sensor in the Unknown fired with value 0.363248.',
#  'After 2.92 seconds, Unknown sensor in the Unknown fired with value 0.304653.',
#  'After 8.59 seconds, Unknown sensor in the Unknown fired with value 0.231136.',
#  'After 1.68 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 3.82 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 2.89 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.92 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.64 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.61 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 3.07 seconds, Motion sensor in the Attic fired with value OFF.',
#  'Motion sensor in the Basement fired with value ON at eleven hours one minutes AM.',
#  'After 12.84 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 1.51 seconds, Motion sensor in the Closet fired with value ON.',
#  'After 0.56 seconds, Motion sensor in the Porch fired with value ON.',
#  'After 2.21 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 0.04 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.66 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 0.36 seconds, Motion sensor in the Closet fired with value OFF.',
#  'After 1.72 seconds, Motion sensor in the Porch fired with value OFF.',
#  'After 0.34 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 3.0 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.08 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 3.29 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.97 seconds, Motion sensor in the Unknown fired with value OFF.',
#  'After 5.29 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 0.37 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.13 seconds, Motion sensor in the Unknown fired with value OFF.',
#  'After 2.42 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.06 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 8.51 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.61 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 3.93 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 2.71 seconds, Unknown sensor in the Unknown fired with value 0.0448444.',
#  'After 2.98 seconds, Unknown sensor in the Unknown fired with value 0.138401.',
#  'After 42.4 seconds, Unknown sensor in the Unknown fired with value 0.275981.',
#  'After 3.21 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.81 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 24.58 seconds, Unknown sensor in the Unknown fired with value 0.22598.',
#  'After 3.75 seconds, Unknown sensor in the Unknown fired with value 0.286176.',
#  'After 2.16 seconds, Unknown sensor in the Unknown fired with value 0.213011.',
#  'After 12.74 seconds, Unknown sensor in the Unknown fired with value 0.287153.',
#  'After 5.97 seconds, Unknown sensor in the Unknown fired with value 0.222777.',
#  'After 5.83 seconds, Unknown sensor in the Unknown fired with value 0.300005.',
#  'After 32.99 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 1.91 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 0.32 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.59 seconds, Motion sensor in the Unknown fired with value OFF.',
#  'After 0.76 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 24.94 seconds, Unknown sensor in the Unknown fired with value 0.244418.',
#  'After 3.23 seconds, Unknown sensor in the Unknown fired with value 0.346529.',
#  'After 4.6 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.78 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 33.58 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.17 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 0.97 seconds, Motion sensor in the Unknown fired with value OFF.',
#  'After 1.27 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 16.53 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.82 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 12.08 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.0 seconds, Unknown sensor in the Unknown fired with value 0.222347.',
#  'After 1.7 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.79 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 3.17 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.34 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 0.28 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.52 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.63 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.09 seconds, Door sensor in the Living Room fired with value OPEN.',
#  'After 0.95 seconds, Motion sensor in the Unknown fired with value OFF.',
#  'After 1.84 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 3.64 seconds, Item sensor in the Kitchen fired with value PRESENT.',
#  'After 1.38 seconds, Item sensor in the Living Room fired with value PRESENT.',
#  'After 3.0 seconds, Item sensor in the Hallway fired with value PRESENT.',
#  'After 4.36 seconds, Door sensor in the Living Room fired with value CLOSE.',
#  'Motion sensor in the Attic fired with value ON at eleven hours thirty-one minutes AM.',
#  'After 0.39 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 1.56 seconds, Motion sensor in the Unknown fired with value OFF.',
#  'After 2.9 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.05 seconds, Door sensor in the Living Room fired with value OPEN.',
#  'After 1.22 seconds, Unknown sensor in the Unknown fired with value 2.84247.',
#  'After 0.44 seconds, Item sensor in the Living Room fired with value ABSENT.',
#  'After 2.06 seconds, Unknown sensor in the Unknown fired with value 2.97669.',
#  'After 2.03 seconds, Item sensor in the Kitchen fired with value ABSENT.',
#  'After 0.91 seconds, Unknown sensor in the Unknown fired with value 3.06669.',
#  'After 3.04 seconds, Unknown sensor in the Unknown fired with value 3.12919.',
#  'After 5.71 seconds, Item sensor in the Garage fired with value ABSENT.',
#  'After 0.27 seconds, Unknown sensor in the Unknown fired with value 3.18661.',
#  'After 0.75 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.98 seconds, Item sensor in the Bathroom fired with value ABSENT.',
#  'After 1.37 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.41 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.46 seconds, Unknown sensor in the Unknown fired with value 3.24005.',
#  'After 2.32 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.18 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 4.53 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.05 seconds, Unknown sensor in the Unknown fired with value 0.0388678.',
#  'After 6.26 seconds, Unknown sensor in the Unknown fired with value 3.15638.',
#  'After 2.99 seconds, Unknown sensor in the Unknown fired with value 0.218988.',
#  'After 2.93 seconds, Unknown sensor in the Unknown fired with value 0.0855091.',
#  'After 0.1 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 3.21 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 2.72 seconds, Unknown sensor in the Unknown fired with value 3.07966.',
#  'After 1.6 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 3.83 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 12.96 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 4.91 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.22 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.31 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 12.59 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.96 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 10.43 seconds, Unknown sensor in the Unknown fired with value 3.02809.',
#  'After 6.79 seconds, Unknown sensor in the Unknown fired with value 3.12677.',
#  'After 4.5 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 3.92 seconds, Unknown sensor in the Unknown fired with value 3.21646.',
#  'After 12.16 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 3.69 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.29 seconds, Motion sensor in the Unknown fired with value OFF.',
#  'After 2.97 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 21.0 seconds, Item sensor in the Kitchen fired with value PRESENT.',
#  'After 0.74 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 3.27 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 13.66 seconds, Unknown sensor in the Unknown fired with value 3.29114.',
#  'After 6.0 seconds, Unknown sensor in the Unknown fired with value 3.34583.',
#  'After 3.0 seconds, Unknown sensor in the Unknown fired with value 3.21981.',
#  'After 2.99 seconds, Unknown sensor in the Unknown fired with value 3.11184.',
#  'After 5.98 seconds, Unknown sensor in the Unknown fired with value 3.02481.',
#  'After 20.94 seconds, Unknown sensor in the Unknown fired with value 2.9427.',
#  'After 48.34 seconds, Unknown sensor in the Unknown fired with value 3.01739.',
#  'After 1.2 seconds, Item sensor in the Bedroom 1 fired with value ABSENT.',
#  'After 4.55 seconds, Unknown sensor in the Unknown fired with value 2.96481.',
#  'After 17.95 seconds, Unknown sensor in the Unknown fired with value 2.88004.',
#  'After 14.47 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.79 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 17.72 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.35 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.5 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.71 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 51.68 seconds, Item sensor in the Bedroom 2 fired with value ABSENT.',
#  'After 13.02 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.51 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 33.45 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 36.42 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.45 seconds, Unknown sensor in the Unknown fired with value 0.0345708.',
#  'After 2.99 seconds, Unknown sensor in the Unknown fired with value 0.452858.',
#  'After 2.32 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 0.72 seconds, Unknown sensor in the Unknown fired with value 0.185393.',
#  'After 0.0 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.2 seconds, Motion sensor in the Unknown fired with value OFF.',
#  'After 1.74 seconds, Unknown sensor in the Unknown fired with value 0.0996109.',
#  'After 0.3 seconds, Item sensor in the Hallway fired with value ABSENT.',
#  'After 0.28 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 11.74 seconds, Motion sensor in the Porch fired with value ON.',
#  'After 0.27 seconds, Motion sensor in the Closet fired with value ON.',
#  'After 0.7 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 2.01 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 1.31 seconds, Motion sensor in the Porch fired with value OFF.',
#  'After 0.16 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 1.57 seconds, Motion sensor in the Closet fired with value OFF.',
#  'After 0.99 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 0.66 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 2.57 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 0.85 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 7.01 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 2.21 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 1.03 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 2.66 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 1.88 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 0.25 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 2.1 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 0.62 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 5.08 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 1.15 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 5.81 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 3.48 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 0.63 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 1.79 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 1.16 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 3.01 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 5.48 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 1.76 seconds, Motion sensor in the Basement fired with value OFF.',
#  'Motion sensor in the Attic fired with value ON at eleven hours seven minutes AM.',
#  'After 2.65 seconds, Unknown sensor in the Unknown fired with value 0.0540633.',
#  'After 2.23 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.59 seconds, Unknown sensor in the Unknown fired with value 0.190003.',
#  'After 2.72 seconds, Unknown sensor in the Unknown fired with value 0.0573837.',
#  'After 0.0 seconds, Unknown sensor in the Unknown fired with value 0.246918.',
#  'After 2.92 seconds, Unknown sensor in the Unknown fired with value 0.398522.',
#  'After 0.0 seconds, Unknown sensor in the Unknown fired with value 0.213831.',
#  'After 0.56 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.19 seconds, Door sensor in the Living Room fired with value OPEN.',
#  'After 0.92 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.68 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.77 seconds, Item sensor in the Hallway fired with value ABSENT.',
#  'After 0.12 seconds, Unknown sensor in the Unknown fired with value 0.114064.',
#  'After 0.0 seconds, Unknown sensor in the Unknown fired with value 0.198128.',
#  'After 0.92 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.14 seconds, Door sensor in the Living Room fired with value CLOSE.',
#  'After 5.44 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.78 seconds, Motion sensor in the Porch fired with value ON.',
#  'After 0.42 seconds, Motion sensor in the Closet fired with value ON.',
#  'After 0.68 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 1.54 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.21 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 0.52 seconds, Motion sensor in the Closet fired with value OFF.',
#  'After 0.32 seconds, Motion sensor in the Porch fired with value OFF.',
#  'After 6.61 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 0.48 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 0.74 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 1.03 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 14.02 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 2.16 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 17.63 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 6.02 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 2.13 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 7.13 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 8.97 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 1.03 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 24.92 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 1.57 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 8.65 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 2.04 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 0.75 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 1.03 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 2.87 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 1.34 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 2.96 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 1.56 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 2.89 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 2.47 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 1.73 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 1.01 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 48.15 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 1.02 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 56.62 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 2.13 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 5.17 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 1.25 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 0.95 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 2.7 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 7.29 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 1.59 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 17.48 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 2.6 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 41.99 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 0.0 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 0.65 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 2.77 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 5.59 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 2.47 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 6.55 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 2.2 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 0.14 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 2.94 seconds, Motion sensor in the Basement fired with value OFF.',
#  'Motion sensor in the Attic fired with value ON at ten hours fifty-seven minutes AM.',
#  'After 5.81 seconds, Door sensor in the Living Room fired with value OPEN.',
#  'After 4.08 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.38 seconds, Item sensor in the Garage fired with value ABSENT.',
#  'After 0.97 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.34 seconds, Item sensor in the Kitchen fired with value ABSENT.',
#  'After 2.7 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.05 seconds, Item sensor in the Bathroom fired with value ABSENT.',
#  'After 0.31 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 5.15 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 2.44 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.96 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.27 seconds, Unknown sensor in the Unknown fired with value 0.0369537.',
#  'After 3.06 seconds, Unknown sensor in the Unknown fired with value 0.138479.',
#  'After 0.0 seconds, Unknown sensor in the Unknown fired with value 0.0375787.',
#  'After 5.71 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.34 seconds, Unknown sensor in the Unknown fired with value 0.196097.',
#  'After 3.3 seconds, Door sensor in the Living Room fired with value CLOSE.',
#  'After 1.71 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 3.27 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.85 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 7.33 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.6 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 13.97 seconds, Unknown sensor in the Unknown fired with value 2.82895.',
#  'After 2.89 seconds, Unknown sensor in the Unknown fired with value 2.93879.',
#  'After 2.24 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.14 seconds, Unknown sensor in the Unknown fired with value 3.01434.',
#  'After 2.63 seconds, Unknown sensor in the Unknown fired with value 3.09442.',
#  'After 4.26 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.52 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.7 seconds, Unknown sensor in the Unknown fired with value 3.16497.',
#  'After 1.56 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 2.97 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 3.45 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 2.68 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.82 seconds, Unknown sensor in the Unknown fired with value 3.24278.',
#  'After 6.04 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.42 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 4.94 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 3.01 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.31 seconds, Unknown sensor in the Unknown fired with value 3.30005.',
#  'After 4.1 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 5.4 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.85 seconds, Door sensor in the Living Room fired with value OPEN.',
#  'After 1.32 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 2.35 seconds, Item sensor in the Kitchen fired with value PRESENT.',
#  'After 15.36 seconds, Unknown sensor in the Unknown fired with value 3.24177.',
#  'After 1.72 seconds, Item sensor in the Living Room fired with value ABSENT.',
#  'After 2.01 seconds, Item sensor in the Bedroom 1 fired with value ABSENT.',
#  'After 6.39 seconds, Door sensor in the Living Room fired with value CLOSE.',
#  'After 17.17 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.3 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.13 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 9.63 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.23 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 2.97 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.2 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 2.28 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.65 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.88 seconds, Unknown sensor in the Unknown fired with value 3.19106.',
#  'After 2.73 seconds, Unknown sensor in the Unknown fired with value 3.13489.',
#  'After 1.25 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.53 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.5 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 5.18 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.23 seconds, Unknown sensor in the Unknown fired with value 3.1945.',
#  'After 1.32 seconds, Door sensor in the Living Room fired with value OPEN.',
#  'After 0.46 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.97 seconds, Item sensor in the Bedroom 2 fired with value ABSENT.',
#  'After 0.86 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 8.84 seconds, Item sensor in the Living Room fired with value PRESENT.',
#  'After 0.84 seconds, Door sensor in the Living Room fired with value CLOSE.',
#  'After 1.9 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.88 seconds, Unknown sensor in the Unknown fired with value 0.038399.',
#  'After 0.23 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 3.05 seconds, Unknown sensor in the Unknown fired with value 0.293012.',
#  'After 0.06 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.87 seconds, Unknown sensor in the Unknown fired with value 0.242074.',
#  'After 1.43 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 52.26 seconds, Unknown sensor in the Unknown fired with value 3.14434.',
#  'After 5.95 seconds, Unknown sensor in the Unknown fired with value 3.19552.',
#  'After 15.0 seconds, Unknown sensor in the Unknown fired with value 3.12434.',
#  'After 3.84 seconds, Unknown sensor in the Unknown fired with value 3.02919.',
#  'After 6.0 seconds, Unknown sensor in the Unknown fired with value 2.97715.',
#  'After 11.32 seconds, Unknown sensor in the Unknown fired with value 2.89708.',
#  'After 50.94 seconds, Unknown sensor in the Unknown fired with value 2.83879.',
#  'After 44.99 seconds, Unknown sensor in the Unknown fired with value 2.90465.',
#  'After 38.41 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 5.54 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.01 seconds, Unknown sensor in the Unknown fired with value 0.0421491.',
#  'After 6.08 seconds, Unknown sensor in the Unknown fired with value 0.169065.',
#  'After 41.95 seconds, Unknown sensor in the Unknown fired with value 0.0414459.',
#  'After 3.5 seconds, Unknown sensor in the Unknown fired with value 0.301801.',
#  'After 5.49 seconds, Unknown sensor in the Unknown fired with value 0.417584.',
#  'After 6.06 seconds, Unknown sensor in the Unknown fired with value 0.486921.',
#  'After 2.9 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.54 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.12 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.06 seconds, Motion sensor in the Attic fired with value OFF.',
#  'Motion sensor in the Stairs fired with value ON at one hours one minutes PM.',
#  'After 0.19 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 1.88 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 2.04 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 0.14 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 1.71 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 14.53 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 0.19 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 3.6 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 5.04 seconds, Motion sensor in the Closet fired with value ON.',
#  'After 0.67 seconds, Motion sensor in the Porch fired with value ON.',
#  'After 1.51 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.62 seconds, Motion sensor in the Closet fired with value OFF.',
#  'After 1.07 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 0.6 seconds, Motion sensor in the Porch fired with value OFF.',
#  'After 1.77 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.28 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.93 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 5.0 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 3.01 seconds, Door sensor in the Living Room fired with value OPEN.',
#  'After 5.49 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.23 seconds, Item sensor in the Bedroom 2 fired with value PRESENT.',
#  'After 2.39 seconds, Item sensor in the Bedroom 1 fired with value PRESENT.',
#  'After 1.97 seconds, Item sensor in the Hallway fired with value PRESENT.',
#  'After 2.17 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.25 seconds, Door sensor in the Living Room fired with value CLOSE.',
#  'After 10.72 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 6.29 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 3.74 seconds, Motion sensor in the Unknown fired with value OFF.',
#  'After 0.64 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 0.86 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 3.16 seconds, Motion sensor in the Unknown fired with value OFF.',
#  'After 0.16 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 3.76 seconds, Unknown sensor in the Unknown fired with value 0.0676182.',
#  'After 3.6 seconds, Unknown sensor in the Unknown fired with value 0.277075.',
#  'After 41.28 seconds, Unknown sensor in the Unknown fired with value 0.434733.',
#  'After 2.99 seconds, Unknown sensor in the Unknown fired with value 0.344849.',
#  'After 81.03 seconds, Unknown sensor in the Unknown fired with value 0.0508211.',
#  'After 2.96 seconds, Unknown sensor in the Unknown fired with value 0.419811.',
#  'After 23.39 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 1.45 seconds, Motion sensor in the Unknown fired with value OFF.',
#  'After 28.16 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.97 seconds, Unknown sensor in the Unknown fired with value 0.476374.',
#  'After 0.43 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 1.06 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 4.2 seconds, Motion sensor in the Unknown fired with value OFF.',
#  'After 1.95 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 0.48 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.54 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 3.43 seconds, Unknown sensor in the Unknown fired with value 0.0590243.',
#  'After 1.14 seconds, Motion sensor in the Unknown fired with value OFF.',
#  'After 0.14 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.68 seconds, Unknown sensor in the Unknown fired with value 0.364185.',
#  'After 13.57 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.38 seconds, Unknown sensor in the Unknown fired with value 0.486101.',
#  'After 3.02 seconds, Unknown sensor in the Unknown fired with value 0.103908.',
#  'After 4.44 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 3.18 seconds, Motion sensor in the Unknown fired with value OFF.',
#  'Motion sensor in the Stairs fired with value OFF at two hours nine minutes PM.',
#  'After 0.92 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 1.94 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 2.16 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 1.29 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 0.29 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 0.32 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 0.86 seconds, Motion sensor in the Closet fired with value ON.',
#  'After 0.49 seconds, Motion sensor in the Porch fired with value ON.',
#  'After 1.35 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.15 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 0.78 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 0.2 seconds, Motion sensor in the Closet fired with value OFF.',
#  'After 0.5 seconds, Motion sensor in the Porch fired with value OFF.',
#  'After 2.54 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.57 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.48 seconds, Door sensor in the Living Room fired with value OPEN.',
#  'After 1.45 seconds, Item sensor in the Hallway fired with value PRESENT.',
#  'After 2.1 seconds, Door sensor in the Living Room fired with value CLOSE.',
#  'After 4.6 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 3.32 seconds, Unknown sensor in the Unknown fired with value 0.0342583.',
#  'After 2.34 seconds, Unknown sensor in the Unknown fired with value 0.297114.',
#  'After 2.91 seconds, Unknown sensor in the Unknown fired with value 0.458054.',
#  'After 3.07 seconds, Unknown sensor in the Unknown fired with value 0.511336.',
#  'After 3.35 seconds, Unknown sensor in the Unknown fired with value 0.47739.',
#  'After 5.94 seconds, Unknown sensor in the Unknown fired with value 0.501844.',
#  'After 2.71 seconds, Unknown sensor in the Unknown fired with value 0.467195.',
#  'After 3.03 seconds, Unknown sensor in the Unknown fired with value 0.488523.',
#  'After 2.99 seconds, Unknown sensor in the Unknown fired with value 0.510398.',
#  'After 2.87 seconds, Unknown sensor in the Unknown fired with value 0.486765.',
#  'After 3.34 seconds, Unknown sensor in the Unknown fired with value 0.514969.',
#  'After 2.91 seconds, Unknown sensor in the Unknown fired with value 0.46571.',
#  'After 8.83 seconds, Unknown sensor in the Unknown fired with value 0.489617.',
#  'After 15.36 seconds, Unknown sensor in the Unknown fired with value 0.509891.',
#  'After 5.56 seconds, Unknown sensor in the Unknown fired with value 0.459616.',
#  'After 9.13 seconds, Unknown sensor in the Unknown fired with value 0.483953.',
#  'After 5.84 seconds, Unknown sensor in the Unknown fired with value 0.504383.',
#  'After 6.19 seconds, Unknown sensor in the Unknown fired with value 0.47989.',
#  'After 2.92 seconds, Unknown sensor in the Unknown fired with value 0.452116.',
#  'After 2.91 seconds, Unknown sensor in the Unknown fired with value 0.484343.',
#  'After 3.87 seconds, Unknown sensor in the Unknown fired with value 0.511141.',
#  'After 2.26 seconds, Unknown sensor in the Unknown fired with value 0.488406.',
#  'After 3.41 seconds, Unknown sensor in the Unknown fired with value 0.533485.',
#  'After 20.64 seconds, Unknown sensor in the Unknown fired with value 0.491531.',
#  'After 2.85 seconds, Unknown sensor in the Unknown fired with value 0.466726.',
#  'After 6.15 seconds, Unknown sensor in the Unknown fired with value 0.492742.',
#  'After 2.92 seconds, Unknown sensor in the Unknown fired with value 0.515711.',
#  'After 2.89 seconds, Unknown sensor in the Unknown fired with value 0.47782.',
#  'After 1.85 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 2.84 seconds, Motion sensor in the Unknown fired with value OFF.',
#  'After 1.46 seconds, Unknown sensor in the Unknown fired with value 0.455554.',
#  'After 5.92 seconds, Unknown sensor in the Unknown fired with value 0.491257.',
#  'After 3.07 seconds, Unknown sensor in the Unknown fired with value 0.530594.',
#  'After 0.3 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 1.6 seconds, Motion sensor in the Unknown fired with value OFF.',
#  'After 9.98 seconds, Unknown sensor in the Unknown fired with value 0.49032.',
#  'After 3.61 seconds, Unknown sensor in the Unknown fired with value 0.515438.',
#  'After 5.59 seconds, Unknown sensor in the Unknown fired with value 0.491375.',
#  'After 2.86 seconds, Unknown sensor in the Unknown fired with value 0.455671.',
#  'After 3.07 seconds, Unknown sensor in the Unknown fired with value 0.499304.',
#  'After 3.67 seconds, Unknown sensor in the Unknown fired with value 0.376099.',
#  'After 2.26 seconds, Unknown sensor in the Unknown fired with value 0.0567196.',
#  'After 3.18 seconds, Unknown sensor in the Unknown fired with value 0.295669.',
#  'After 2.72 seconds, Unknown sensor in the Unknown fired with value 0.0770324.',
#  'After 0.0 seconds, Unknown sensor in the Unknown fired with value 0.0369146.',
#  'After 3.83 seconds, Unknown sensor in the Unknown fired with value 0.157737.',
#  'After 0.0 seconds, Unknown sensor in the Unknown fired with value 0.0755871.',
#  'After 2.35 seconds, Unknown sensor in the Unknown fired with value 0.234183.',
#  'After 0.23 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 0.75 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.26 seconds, Motion sensor in the Unknown fired with value OFF.',
#  'After 1.34 seconds, Unknown sensor in the Unknown fired with value 0.167776.',
#  'Motion sensor in the Stairs fired with value ON at one hours fifty-seven minutes PM.',
#  'After 1.13 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 1.9 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 1.09 seconds, Motion sensor in the Closet fired with value ON.',
#  'After 0.29 seconds, Motion sensor in the Porch fired with value ON.',
#  'After 1.02 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.61 seconds, Motion sensor in the Closet fired with value OFF.',
#  'After 0.98 seconds, Motion sensor in the Porch fired with value OFF.',
#  'After 0.0 seconds, Unknown sensor in the Unknown fired with value 0.037774.',
#  'After 0.26 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 2.01 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.99 seconds, Unknown sensor in the Unknown fired with value 0.0827356.',
#  'After 2.48 seconds, Unknown sensor in the Unknown fired with value 0.233324.',
#  'After 2.97 seconds, Unknown sensor in the Unknown fired with value 0.202581.',
#  'After 6.24 seconds, Unknown sensor in the Unknown fired with value 0.254809.',
#  'After 11.88 seconds, Unknown sensor in the Unknown fired with value 0.223949.',
#  'After 3.24 seconds, Unknown sensor in the Unknown fired with value 0.258402.',
#  'After 1.32 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.98 seconds, Unknown sensor in the Unknown fired with value 0.0617588.',
#  'After 1.79 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.7 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 6.7 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 2.69 seconds, Item sensor in the Garage fired with value ABSENT.',
#  'After 1.16 seconds, Motion sensor in the Unknown fired with value OFF.',
#  'After 4.12 seconds, Item sensor in the Garage fired with value PRESENT.',
#  'Motion sensor in the Stairs fired with value ON at twelve hours forty-nine minutes PM.',
#  'After 1.18 seconds, Motion sensor in the Closet fired with value ON.',
#  'After 0.44 seconds, Motion sensor in the Porch fired with value ON.',
#  'After 1.23 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.0 seconds, Motion sensor in the Closet fired with value OFF.',
#  'After 0.34 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 1.74 seconds, Motion sensor in the Porch fired with value OFF.',
#  'After 0.17 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 0.39 seconds, Unknown sensor in the Unknown fired with value 0.0332818.',
#  'After 1.09 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.91 seconds, Unknown sensor in the Unknown fired with value 0.302934.',
#  'After 9.15 seconds, Unknown sensor in the Unknown fired with value 0.471413.',
#  'After 14.96 seconds, Unknown sensor in the Unknown fired with value 0.538329.',
#  'After 13.49 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.81 seconds, Unknown sensor in the Unknown fired with value 0.467429.',
#  'After 2.0 seconds, Motion sensor in the Attic fired with value OFF.',
#  'Motion sensor in the Basement fired with value ON at eleven hours forty-one minutes AM.',
#  'After 11.99 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 1.05 seconds, Motion sensor in the Closet fired with value ON.',
#  'After 0.41 seconds, Motion sensor in the Porch fired with value ON.',
#  'After 1.61 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.0 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.8 seconds, Motion sensor in the Closet fired with value OFF.',
#  'After 0.13 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 0.13 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 1.91 seconds, Motion sensor in the Porch fired with value OFF.',
#  'After 0.49 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.21 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 5.33 seconds, Item sensor in the Hallway fired with value PRESENT.',
#  'After 0.0 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 3.64 seconds, Item sensor in the Bedroom 2 fired with value PRESENT.',
#  'After 2.4 seconds, Item sensor in the Bedroom 2 fired with value ABSENT.',
#  'After 0.87 seconds, Item sensor in the Living Room fired with value PRESENT.',
#  'After 10.3 seconds, Motion sensor in the Attic fired with value ON.',
# ...
#  'After 0.45 seconds, Motion sensor in the Closet fired with value ON.',
#  'After 0.63 seconds, Motion sensor in the Stairs fired with value ON.',
#  'After 1.82 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 1.09 seconds, Motion sensor in the Porch fired with value OFF.',
#  'After 0.14 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.24 seconds, Motion sensor in the Closet fired with value ON.',
#  'After 1.22 seconds, Motion sensor in the Closet fired with value OFF.',
#  'After 0.32 seconds, Motion sensor in the Stairs fired with value OFF.',
#  'After 4.95 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 0.22 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 4.21 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 1.97 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 4.76 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 3.17 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 5.98 seconds, Motion sensor in the Basement fired with value OFF.',
#  'After 3.54 seconds, Motion sensor in the Basement fired with value ON.',
#  'After 9.18 seconds, Motion sensor in the Basement fired with value OFF.',
#  'Item sensor in the Garage fired with value ABSENT at ten hours fifty-four minutes AM.',
#  'After 3.92 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 2.09 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.81 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.27 seconds, Door sensor in the Living Room fired with value OPEN.',
#  'After 0.44 seconds, Unknown sensor in the Unknown fired with value 2.8145.',
#  'After 0.41 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.38 seconds, Item sensor in the Living Room fired with value ABSENT.',
#  'After 1.79 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.4 seconds, Unknown sensor in the Unknown fired with value 2.88004.',
#  'After 3.11 seconds, Unknown sensor in the Unknown fired with value 3.00348.',
#  'After 3.0 seconds, Unknown sensor in the Unknown fired with value 3.07622.',
#  'After 2.32 seconds, Door sensor in the Living Room fired with value CLOSE.',
#  'After 2.74 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.82 seconds, Unknown sensor in the Unknown fired with value 3.13911.',
#  'After 1.11 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 5.01 seconds, Unknown sensor in the Unknown fired with value 3.22302.',
#  'After 41.93 seconds, Unknown sensor in the Unknown fired with value 3.2795.',
#  'After 5.82 seconds, Door sensor in the Living Room fired with value OPEN.',
#  'After 0.56 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.69 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.4 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.12 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.79 seconds, Door sensor in the Living Room fired with value CLOSE.',
#  'After 0.33 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 6.93 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 25.11 seconds, Door sensor in the Living Room fired with value OPEN.',
#  'After 1.66 seconds, Door sensor in the Living Room fired with value CLOSE.',
#  'After 0.59 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 3.69 seconds, Door sensor in the Living Room fired with value OPEN.',
#  'After 4.14 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.47 seconds, Item sensor in the Bedroom 1 fired with value ABSENT.',
#  'After 4.52 seconds, Item sensor in the Bedroom 1 fired with value PRESENT.',
#  'After 1.96 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 4.96 seconds, Item sensor in the Bedroom 2 fired with value ABSENT.',
#  'After 1.58 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 5.92 seconds, Item sensor in the Living Room fired with value PRESENT.',
#  'After 2.03 seconds, Item sensor in the Kitchen fired with value PRESENT.',
#  'After 3.44 seconds, Door sensor in the Living Room fired with value CLOSE.',
#  'After 2.08 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 4.4 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.09 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 7.98 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.46 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.08 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 19.98 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.88 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.94 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.1 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.8 seconds, Door sensor in the Living Room fired with value OPEN.',
#  'After 7.18 seconds, Door sensor in the Living Room fired with value CLOSE.',
#  'After 15.42 seconds, Unknown sensor in the Unknown fired with value 3.32966.',
#  'After 0.9 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.01 seconds, Unknown sensor in the Unknown fired with value 3.23286.',
#  'After 1.42 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.35 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.27 seconds, Unknown sensor in the Unknown fired with value 3.12372.',
#  'After 0.46 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.12 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.65 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.94 seconds, Unknown sensor in the Unknown fired with value 3.04739.',
#  'After 12.31 seconds, Unknown sensor in the Unknown fired with value 2.97989.',
#  'After 0.48 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 5.02 seconds, Unknown sensor in the Unknown fired with value 3.04427.',
#  'After 0.33 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.29 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.04 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 27.28 seconds, Unknown sensor in the Unknown fired with value 2.98614.',
#  'After 39.63 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.01 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 21.79 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 3.64 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 2.02 seconds, Unknown sensor in the Unknown fired with value 3.04692.',
#  'After 5.86 seconds, Unknown sensor in the Unknown fired with value 2.98153.',
#  'After 6.11 seconds, Unknown sensor in the Unknown fired with value 2.90926.',
#  'Motion sensor in the Attic fired with value ON at ten hours fifty minutes AM.',
#  'After 0.76 seconds, Door sensor in the Living Room fired with value OPEN.',
#  'After 2.74 seconds, Item sensor in the Kitchen fired with value ABSENT.',
#  'After 0.31 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 2.13 seconds, Item sensor in the Living Room fired with value ABSENT.',
#  'After 3.37 seconds, Item sensor in the Bedroom 2 fired with value ABSENT.',
#  'After 3.82 seconds, Item sensor in the Bathroom fired with value ABSENT.',
#  'After 4.44 seconds, Item sensor in the Bedroom 1 fired with value ABSENT.',
#  'After 7.77 seconds, Item sensor in the Garage fired with value ABSENT.',
#  'After 3.0 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.77 seconds, Door sensor in the Living Room fired with value CLOSE.',
#  'After 6.14 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 2.18 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.36 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 2.48 seconds, Unknown sensor in the Unknown fired with value 0.053243.',
#  'After 2.97 seconds, Unknown sensor in the Unknown fired with value 0.293442.',
#  'After 0.85 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.89 seconds, Unknown sensor in the Unknown fired with value 0.207152.',
#  'After 2.27 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 4.1 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 8.68 seconds, Unknown sensor in the Unknown fired with value 2.80637.',
#  'After 0.39 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.35 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.7 seconds, Unknown sensor in the Unknown fired with value 2.96583.',
#  'After 2.56 seconds, Unknown sensor in the Unknown fired with value 3.07091.',
#  'After 6.06 seconds, Unknown sensor in the Unknown fired with value 3.12466.',
#  'After 2.68 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 4.32 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.86 seconds, Unknown sensor in the Unknown fired with value 3.22771.',
#  'After 1.57 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.29 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 3.52 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.62 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 4.39 seconds, Motion sensor in the Unknown fired with value OFF.',
#  'After 0.27 seconds, Unknown sensor in the Unknown fired with value 3.29622.',
#  'After 2.75 seconds, Unknown sensor in the Unknown fired with value 3.16458.',
#  'After 0.08 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 2.53 seconds, Unknown sensor in the Unknown fired with value 3.21747.',
#  'After 21.05 seconds, Unknown sensor in the Unknown fired with value 3.16005.',
#  'After 2.15 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.08 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 11.28 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.96 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.06 seconds, Unknown sensor in the Unknown fired with value 3.10606.',
#  'After 5.42 seconds, Unknown sensor in the Unknown fired with value 3.16005.',
#  'After 8.98 seconds, Unknown sensor in the Unknown fired with value 3.23411.',
#  'After 59.73 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 5.7 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.35 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 5.73 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 5.25 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 2.81 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.97 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 4.01 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.27 seconds, Motion sensor in the Unknown fired with value ON.',
#  'After 3.23 seconds, Motion sensor in the Unknown fired with value OFF.',
#  'After 1.3 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 15.22 seconds, Unknown sensor in the Unknown fired with value 3.2956.',
#  'After 2.93 seconds, Unknown sensor in the Unknown fired with value 3.13974.',
#  'After 2.92 seconds, Unknown sensor in the Unknown fired with value 3.05669.',
#  'After 5.83 seconds, Unknown sensor in the Unknown fired with value 2.99278.',
#  'After 4.48 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.11 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.51 seconds, Unknown sensor in the Unknown fired with value 2.9134.',
#  'After 20.69 seconds, Unknown sensor in the Unknown fired with value 2.98278.',
#  'After 68.25 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.57 seconds, Unknown sensor in the Unknown fired with value 3.04427.',
#  'After 1.02 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 4.65 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.12 seconds, Unknown sensor in the Unknown fired with value 2.98528.',
#  'After 8.7 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 3.44 seconds, Unknown sensor in the Unknown fired with value 2.90215.',
#  'After 4.92 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 3.65 seconds, Motion sensor in the Attic fired with value ON.',
#  'Motion sensor in the Attic fired with value ON at twelve hours fifty minutes PM.',
#  'After 12.71 seconds, Item sensor in the Garage fired with value ABSENT.',
#  'After 5.36 seconds, Door sensor in the Living Room fired with value OPEN.',
#  'After 2.2 seconds, Item sensor in the Kitchen fired with value ABSENT.',
#  'After 2.15 seconds, Item sensor in the Bedroom 1 fired with value ABSENT.',
#  'After 3.85 seconds, Item sensor in the Living Room fired with value ABSENT.',
#  'After 0.68 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 1.0 seconds, Item sensor in the Bedroom 2 fired with value ABSENT.',
#  'After 1.02 seconds, Item sensor in the Bathroom fired with value ABSENT.',
#  'After 4.23 seconds, Door sensor in the Living Room fired with value CLOSE.',
#  'After 8.7 seconds, Unknown sensor in the Unknown fired with value 0.0338677.',
#  'After 0.03 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 2.88 seconds, Unknown sensor in the Unknown fired with value 0.129533.',
#  'After 1.64 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 16.28 seconds, Unknown sensor in the Unknown fired with value 2.81965.',
#  'After 2.98 seconds, Unknown sensor in the Unknown fired with value 2.88004.',
#  'After 0.71 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 2.29 seconds, Unknown sensor in the Unknown fired with value 2.99841.',
#  'After 2.73 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.13 seconds, Unknown sensor in the Unknown fired with value 3.07684.',
#  'After 6.54 seconds, Unknown sensor in the Unknown fired with value 3.14442.',
#  'After 6.3 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 2.15 seconds, Unknown sensor in the Unknown fired with value 3.22653.',
#  'After 2.47 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 10.43 seconds, Unknown sensor in the Living Room fired with value STOP_INSTRUCT.',
#  'After 5.76 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 15.95 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.23 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.35 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 3.93 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 11.72 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 0.81 seconds, Door sensor in the Living Room fired with value OPEN.',
#  'After 2.77 seconds, Door sensor in the Living Room fired with value CLOSE.',
#  'After 12.12 seconds, Unknown sensor in the Unknown fired with value 3.28802.',
#  'After 7.17 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 0.33 seconds, Motion sensor in the Porch fired with value ON.',
#  'After 7.32 seconds, Motion sensor in the Porch fired with value OFF.',
#  'After 5.29 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 8.13 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 2.02 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 2.8 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 7.46 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 10.34 seconds, Motion sensor in the Attic fired with value OFF.',
#  'After 1.38 seconds, Motion sensor in the Attic fired with value ON.',
#  'After 19.59 seconds, Motion sensor in the Attic fired with value OFF.',
#  ...]

# %% [markdown]
# __Get GPT output gets the info to put into chatGPT to get a LLM TDOST__

# %%
def get_relative_period(hour):
    """Determine the relative period of the day based on the hour."""
    if 0 <= hour < 5:
        return "Night"
    elif 5 <= hour < 8:
        return "Early Morning"
    elif 8 <= hour < 12:
        return "Morning"
    elif 12 <= hour < 17:
        return "Afternoon"
    elif 17 <= hour < 21:
        return "Evening"
    elif 21 <= hour < 24:
        return "Late Night"
    else:
        return "Unknown"

def get_gpt_output(row):
    # Extract day of the week from the timestamp
    curr_sensor_timestamp = pd.to_datetime(row['Timestamp'])
    day_of_week = curr_sensor_timestamp.strftime('%A')  # e.g., "Monday"

    # Determine the relative period of the day
    period_of_day = get_relative_period(curr_sensor_timestamp.hour)

    # Extract other sensor information
    curr_sensor_type = get_sensor_type(row['Sensor_ID'])
    curr_sensor_location = get_sensor_location(row['Sensor_ID'])
    curr_sensor_value = row['State']

    # Return formatted tuple for the GPT prompt
    return (day_of_week, period_of_day, curr_sensor_type, curr_sensor_location, curr_sensor_value)

# %%
def generate_llm_tdost(sensor_data):
    descriptions = []
    prev_time = None
    for index, row in sensor_data.iterrows():

        description = get_gpt_output(row)

        descriptions.append(description)
    return descriptions

# casas_data['TDOST_Temporal'] = generate_temporal_tdost(casas_data)
# casas_data['TDOST_Temporal']
generate_llm_tdost(casas_data)
# Out:
# [('Thursday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Closet', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Porch', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Porch', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Closet', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '0.0756262'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '0.253324'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '0.355474'),
#  ('Thursday', 'Morning', 'Motion', 'Unknown', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Unknown', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Porch', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Porch', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Closet', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Unknown', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Unknown', 'Living Room', 'START_INSTRUCT'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Unknown', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Door', 'Living Room', 'OPEN'),
#  ('Tuesday', 'Morning', 'Unknown', 'Living Room', 'STOP_INSTRUCT'),
#  ('Tuesday', 'Morning', 'Item', 'Kitchen', 'ABSENT'),
#  ('Tuesday', 'Morning', 'Item', 'Living Room', 'ABSENT'),
#  ('Tuesday', 'Morning', 'Item', 'Living Room', 'PRESENT'),
#  ('Tuesday', 'Morning', 'Item', 'Bathroom', 'ABSENT'),
#  ('Tuesday', 'Morning', 'Door', 'Living Room', 'CLOSE'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.0421491'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.155979'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.223675'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Closet', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Porch', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Porch', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Closet', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Porch', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Door', 'Living Room', 'OPEN'),
#  ('Tuesday', 'Morning', 'Item', 'Hallway', 'PRESENT'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Door', 'Living Room', 'CLOSE'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Unknown', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Unknown', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Unknown', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Unknown', 'OFF'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.0418756'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.221097'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.0433991'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.136682'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.0331255'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.222855'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.369732'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.305942'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.227738'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.363248'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.304653'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.231136'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Unknown', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Closet', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Porch', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Closet', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Porch', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Unknown', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Unknown', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Unknown', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Unknown', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '0.0448444'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '0.138401'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '0.275981'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '0.22598'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '0.286176'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '0.213011'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '0.287153'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '0.222777'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '0.300005'),
#  ('Thursday', 'Morning', 'Motion', 'Unknown', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Unknown', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Unknown', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '0.244418'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '0.346529'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Unknown', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Unknown', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '0.222347'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Unknown', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Door', 'Living Room', 'OPEN'),
#  ('Thursday', 'Morning', 'Motion', 'Unknown', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Item', 'Kitchen', 'PRESENT'),
#  ('Thursday', 'Morning', 'Item', 'Living Room', 'PRESENT'),
#  ('Thursday', 'Morning', 'Item', 'Hallway', 'PRESENT'),
#  ('Thursday', 'Morning', 'Door', 'Living Room', 'CLOSE'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Unknown', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Unknown', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Door', 'Living Room', 'OPEN'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '2.84247'),
#  ('Friday', 'Morning', 'Item', 'Living Room', 'ABSENT'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '2.97669'),
#  ('Friday', 'Morning', 'Item', 'Kitchen', 'ABSENT'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '3.06669'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '3.12919'),
#  ('Friday', 'Morning', 'Item', 'Garage', 'ABSENT'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '3.18661'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Item', 'Bathroom', 'ABSENT'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '3.24005'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.0388678'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '3.15638'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.218988'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.0855091'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '3.07966'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '3.02809'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '3.12677'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '3.21646'),
#  ('Friday', 'Morning', 'Motion', 'Unknown', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Unknown', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Item', 'Kitchen', 'PRESENT'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '3.29114'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '3.34583'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '3.21981'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '3.11184'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '3.02481'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '2.9427'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '3.01739'),
#  ('Friday', 'Morning', 'Item', 'Bedroom 1', 'ABSENT'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '2.96481'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '2.88004'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Item', 'Bedroom 2', 'ABSENT'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.0345708'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.452858'),
#  ('Friday', 'Morning', 'Motion', 'Unknown', 'ON'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.185393'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Unknown', 'OFF'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.0996109'),
#  ('Friday', 'Morning', 'Item', 'Hallway', 'ABSENT'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Porch', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Closet', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Porch', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Closet', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.0540633'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.190003'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.0573837'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.246918'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.398522'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.213831'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Door', 'Living Room', 'OPEN'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Item', 'Hallway', 'ABSENT'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.114064'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.198128'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Door', 'Living Room', 'CLOSE'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Porch', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Closet', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Closet', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Porch', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Door', 'Living Room', 'OPEN'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Item', 'Garage', 'ABSENT'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Item', 'Kitchen', 'ABSENT'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Item', 'Bathroom', 'ABSENT'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.0369537'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.138479'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.0375787'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.196097'),
#  ('Tuesday', 'Morning', 'Door', 'Living Room', 'CLOSE'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '2.82895'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '2.93879'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '3.01434'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '3.09442'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '3.16497'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '3.24278'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '3.30005'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Door', 'Living Room', 'OPEN'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Item', 'Kitchen', 'PRESENT'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '3.24177'),
#  ('Tuesday', 'Morning', 'Item', 'Living Room', 'ABSENT'),
#  ('Tuesday', 'Morning', 'Item', 'Bedroom 1', 'ABSENT'),
#  ('Tuesday', 'Morning', 'Door', 'Living Room', 'CLOSE'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '3.19106'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '3.13489'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '3.1945'),
#  ('Tuesday', 'Morning', 'Door', 'Living Room', 'OPEN'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Item', 'Bedroom 2', 'ABSENT'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Item', 'Living Room', 'PRESENT'),
#  ('Tuesday', 'Morning', 'Door', 'Living Room', 'CLOSE'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.038399'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.293012'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.242074'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '3.14434'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '3.19552'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '3.12434'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '3.02919'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '2.97715'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '2.89708'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '2.83879'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '2.90465'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.0421491'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.169065'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.0414459'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.301801'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.417584'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.486921'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Stairs', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Basement', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Stairs', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Basement', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Stairs', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Basement', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Stairs', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Basement', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Basement', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Closet', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Porch', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Closet', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Stairs', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Porch', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Door', 'Living Room', 'OPEN'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Item', 'Bedroom 2', 'PRESENT'),
#  ('Wednesday', 'Afternoon', 'Item', 'Bedroom 1', 'PRESENT'),
#  ('Wednesday', 'Afternoon', 'Item', 'Hallway', 'PRESENT'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Door', 'Living Room', 'CLOSE'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Unknown', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Unknown', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Unknown', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Unknown', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.0676182'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.277075'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.434733'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.344849'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.0508211'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.419811'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Unknown', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Unknown', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.476374'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Unknown', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Unknown', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Unknown', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Unknown', 'ON'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.0590243'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Unknown', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.364185'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.486101'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.103908'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Unknown', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Unknown', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Stairs', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Stairs', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Basement', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Stairs', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Basement', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Stairs', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Basement', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Closet', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Porch', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Basement', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Stairs', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Closet', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Porch', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Door', 'Living Room', 'OPEN'),
#  ('Wednesday', 'Afternoon', 'Item', 'Hallway', 'PRESENT'),
#  ('Wednesday', 'Afternoon', 'Door', 'Living Room', 'CLOSE'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.0342583'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.297114'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.458054'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.511336'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.47739'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.501844'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.467195'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.488523'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.510398'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.486765'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.514969'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.46571'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.489617'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.509891'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.459616'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.483953'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.504383'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.47989'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.452116'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.484343'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.511141'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.488406'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.533485'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.491531'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.466726'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.492742'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.515711'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.47782'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Unknown', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Unknown', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.455554'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.491257'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.530594'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Unknown', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Unknown', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.49032'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.515438'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.491375'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.455671'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.499304'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.376099'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.0567196'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.295669'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.0770324'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.0369146'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.157737'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.0755871'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.234183'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Unknown', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Unknown', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.167776'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Stairs', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Basement', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Basement', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Closet', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Porch', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Closet', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Porch', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.037774'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Stairs', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.0827356'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.233324'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.202581'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.254809'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.223949'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.258402'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.0617588'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Unknown', 'ON'),
#  ('Wednesday', 'Afternoon', 'Item', 'Garage', 'ABSENT'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Unknown', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Item', 'Garage', 'PRESENT'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Stairs', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Closet', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Porch', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Closet', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Stairs', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Porch', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Basement', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.0332818'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.302934'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.471413'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.538329'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.467429'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Closet', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Porch', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Closet', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Porch', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Item', 'Hallway', 'PRESENT'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Item', 'Bedroom 2', 'PRESENT'),
#  ('Friday', 'Morning', 'Item', 'Bedroom 2', 'ABSENT'),
#  ('Friday', 'Morning', 'Item', 'Living Room', 'PRESENT'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.037774'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.286215'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.531258'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.586962'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.0369928'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.390983'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.173245'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.498679'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.554774'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.492078'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.548876'),
#  ('Friday', 'Morning', 'Motion', 'Unknown', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Unknown', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Unknown', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Unknown', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Unknown', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Unknown', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Unknown', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Unknown', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Unknown', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Unknown', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Unknown', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Unknown', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Unknown', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Unknown', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.49864'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.386178'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Door', 'Living Room', 'CLOSE'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Evening', 'Motion', 'Living Room', 'ON'),
#  ('Tuesday', 'Evening', 'Motion', 'Garage', 'ON'),
#  ('Tuesday', 'Evening', 'Motion', 'Unknown', 'ON'),
#  ('Tuesday', 'Evening', 'Motion', 'Front Door', 'ON'),
#  ('Tuesday', 'Evening', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Evening', 'Motion', 'Garage', 'OFF'),
#  ('Tuesday', 'Evening', 'Motion', 'Unknown', 'OFF'),
#  ('Tuesday', 'Evening', 'Motion', 'Front Door', 'OFF'),
#  ('Tuesday', 'Evening', 'Motion', 'Basement', 'ON'),
#  ('Tuesday', 'Evening', 'Item', 'Front Door', 'ABSENT'),
#  ('Tuesday', 'Evening', 'Motion', 'Living Room', 'OFF'),
#  ('Tuesday', 'Evening', 'Motion', 'Basement', 'OFF'),
#  ('Tuesday', 'Evening', 'Motion', 'Basement', 'ON'),
#  ('Tuesday', 'Evening', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Evening', 'Motion', 'Basement', 'OFF'),
#  ('Tuesday', 'Evening', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Evening', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Evening', 'Motion', 'Basement', 'ON'),
#  ('Tuesday', 'Evening', 'Motion', 'Basement', 'OFF'),
#  ('Tuesday', 'Evening', 'Motion', 'Basement', 'ON'),
#  ('Tuesday', 'Evening', 'Motion', 'Basement', 'OFF'),
#  ('Tuesday', 'Evening', 'Unknown', 'Unknown', 'START'),
#  ('Tuesday', 'Evening', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Evening', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Evening', 'Motion', 'Basement', 'ON'),
#  ('Tuesday', 'Evening', 'Motion', 'Basement', 'OFF'),
#  ('Tuesday', 'Evening', 'Unknown', 'Unknown', 'END'),
#  ('Tuesday', 'Evening', 'Motion', 'Basement', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Closet', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Porch', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Closet', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Porch', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.0630869'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.0322661'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.366685'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.429538'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.206995'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.169924'),
#  ('Friday', 'Morning', 'Unknown', 'Unknown', '0.125002'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Unknown', 'ON'),
#  ('Friday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '0.0629697'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '0.0357818'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '0.129533'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '0.163752'),
#  ('Thursday', 'Morning', 'Door', 'Living Room', 'OPEN'),
#  ('Thursday', 'Morning', 'Item', 'Hallway', 'ABSENT'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Door', 'Living Room', 'CLOSE'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Porch', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Closet', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Porch', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Porch', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Closet', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Door', 'Living Room', 'OPEN'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Item', 'Bedroom 1', 'ABSENT'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Item', 'Hallway', 'ABSENT'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Door', 'Living Room', 'CLOSE'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.0358599'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.234808'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.434186'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '0.215277'),
#  ('Tuesday', 'Morning', 'Motion', 'Porch', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Closet', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Closet', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Porch', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Closet', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Porch', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Porch', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Closet', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Porch', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Closet', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Porch', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Closet', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Closet', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Stairs', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Basement', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Basement', 'OFF'),
#  ('Tuesday', 'Morning', 'Item', 'Garage', 'ABSENT'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Door', 'Living Room', 'OPEN'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '2.8145'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Item', 'Living Room', 'ABSENT'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '2.88004'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '3.00348'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '3.07622'),
#  ('Tuesday', 'Morning', 'Door', 'Living Room', 'CLOSE'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '3.13911'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '3.22302'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '3.2795'),
#  ('Tuesday', 'Morning', 'Door', 'Living Room', 'OPEN'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Door', 'Living Room', 'CLOSE'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Door', 'Living Room', 'OPEN'),
#  ('Tuesday', 'Morning', 'Door', 'Living Room', 'CLOSE'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Door', 'Living Room', 'OPEN'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Item', 'Bedroom 1', 'ABSENT'),
#  ('Tuesday', 'Morning', 'Item', 'Bedroom 1', 'PRESENT'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Item', 'Bedroom 2', 'ABSENT'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Item', 'Living Room', 'PRESENT'),
#  ('Tuesday', 'Morning', 'Item', 'Kitchen', 'PRESENT'),
#  ('Tuesday', 'Morning', 'Door', 'Living Room', 'CLOSE'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Door', 'Living Room', 'OPEN'),
#  ('Tuesday', 'Morning', 'Door', 'Living Room', 'CLOSE'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '3.32966'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '3.23286'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '3.12372'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '3.04739'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '2.97989'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '3.04427'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '2.98614'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Tuesday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '3.04692'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '2.98153'),
#  ('Tuesday', 'Morning', 'Unknown', 'Unknown', '2.90926'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Door', 'Living Room', 'OPEN'),
#  ('Thursday', 'Morning', 'Item', 'Kitchen', 'ABSENT'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Item', 'Living Room', 'ABSENT'),
#  ('Thursday', 'Morning', 'Item', 'Bedroom 2', 'ABSENT'),
#  ('Thursday', 'Morning', 'Item', 'Bathroom', 'ABSENT'),
#  ('Thursday', 'Morning', 'Item', 'Bedroom 1', 'ABSENT'),
#  ('Thursday', 'Morning', 'Item', 'Garage', 'ABSENT'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Door', 'Living Room', 'CLOSE'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '0.053243'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '0.293442'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '0.207152'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '2.80637'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '2.96583'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '3.07091'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '3.12466'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '3.22771'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Unknown', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Unknown', 'OFF'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '3.29622'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '3.16458'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '3.21747'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '3.16005'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '3.10606'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '3.16005'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '3.23411'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Unknown', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Unknown', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '3.2956'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '3.13974'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '3.05669'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '2.99278'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '2.9134'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '2.98278'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '3.04427'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '2.98528'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Thursday', 'Morning', 'Unknown', 'Unknown', '2.90215'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'OFF'),
#  ('Thursday', 'Morning', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Item', 'Garage', 'ABSENT'),
#  ('Wednesday', 'Afternoon', 'Door', 'Living Room', 'OPEN'),
#  ('Wednesday', 'Afternoon', 'Item', 'Kitchen', 'ABSENT'),
#  ('Wednesday', 'Afternoon', 'Item', 'Bedroom 1', 'ABSENT'),
#  ('Wednesday', 'Afternoon', 'Item', 'Living Room', 'ABSENT'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Item', 'Bedroom 2', 'ABSENT'),
#  ('Wednesday', 'Afternoon', 'Item', 'Bathroom', 'ABSENT'),
#  ('Wednesday', 'Afternoon', 'Door', 'Living Room', 'CLOSE'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.0338677'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '0.129533'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '2.81965'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '2.88004'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '2.99841'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '3.07684'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '3.14442'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '3.22653'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Living Room', 'STOP_INSTRUCT'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Door', 'Living Room', 'OPEN'),
#  ('Wednesday', 'Afternoon', 'Door', 'Living Room', 'CLOSE'),
#  ('Wednesday', 'Afternoon', 'Unknown', 'Unknown', '3.28802'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Porch', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Porch', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'OFF'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'ON'),
#  ('Wednesday', 'Afternoon', 'Motion', 'Attic', 'OFF'),
#  ...]
