# %%
import pandas as pd

# %%
# Load the hh101.ann.txt file into a DataFrame
ann_data = pd.read_csv('/Users/harrisonkirstein/Desktop/CSCI-4380-Honors-Option-Repo/CSCI 4380 Honors Option Project/hh101/hh101.ann.txt', delimiter='\t', 
                       names=['Timestamp', 'Sensor_ID', 'Location', 'Zone', 'State', 'Sensor_Type', 'Activity'])

# %%
# Filter out rows where Location or Zone is 'Ignore'
ann_data_filtered = ann_data[(ann_data['Location'] != 'Ignore') & (ann_data['Zone'] != 'Ignore')]
ann_data_filtered
# Out:
#                          Timestamp Sensor_ID     Location   Zone State  \
# 0       2012-07-20 10:38:54.512364      M001  OutsideDoor  Entry    ON
# 5       2012-07-20 10:38:59.541365      M001  OutsideDoor  Entry   OFF
# 7       2012-07-20 10:39:02.429671      M001  OutsideDoor  Entry    ON
# 10      2012-07-20 10:39:04.120443      M001  OutsideDoor  Entry   OFF
# 13      2012-07-20 10:39:36.167078      M001  OutsideDoor  Entry    ON
# ...                            ...       ...          ...    ...   ...
# 321452  2012-09-17 23:52:18.639950      M012      Bedroom    Bed   OFF
# 321453  2012-09-17 23:53:10.229896      M012      Bedroom    Bed    ON
# 321454  2012-09-17 23:53:12.127975      M012      Bedroom    Bed   OFF
# 321455  2012-09-17 23:53:14.730646      M012      Bedroom    Bed    ON
# 321456  2012-09-17 23:53:15.887888      M012      Bedroom    Bed   OFF
#
#             Sensor_Type        Activity
# 0       Control4-Motion        Step_Out
# 5       Control4-Motion        Step_Out
# 7       Control4-Motion        Step_Out
# 10      Control4-Motion        Step_Out
# 13      Control4-Motion        Step_Out
# ...                 ...             ...
# 321452  Control4-Motion  Other_Activity
# 321453  Control4-Motion  Other_Activity
# 321454  Control4-Motion  Other_Activity
# 321455  Control4-Motion  Other_Activity
# 321456  Control4-Motion  Other_Activity
#
# [222858 rows x 7 columns]

# %%
# Helper function to classify time of day
def get_time_period(hour):
    if 0 <= hour < 5:
        return "Night"
    elif 5 <= hour < 8:
        return "Early Morning"
    elif 8 <= hour < 12:
        return "Morning"
    elif 12 <= hour < 17:
        return "Afternoon"
    elif 17 <= hour < 21:
        return "Evening"
    elif 21 <= hour < 24:
        return "Late Night"
    else:
        return "Unknown"

# %%
from datetime import datetime

def timestamp_to_words(timestamp):
    # Parse the timestamp

    # Attempt to parse with milliseconds first
    try:
        dt = datetime.strptime(timestamp, "%Y-%m-%d %H:%M:%S.%f")
    except ValueError:
        # Fall back to parsing without milliseconds
        dt = datetime.strptime(timestamp, "%Y-%m-%d %H:%M:%S")
            
    # Extract hour, minute, and determine AM/PM
    hour = dt.hour
    minute = dt.minute
    period = "AM" if hour < 12 else "PM"
    
    # Adjust hour for 12-hour format
    hour = hour % 12 or 12  # 0 becomes 12 for AM/PM format

    # Convert hour and minute to words
    hour_text = num_to_words(hour)
    minute_text = num_to_words(minute)

    # Form the final text
    return f"{hour_text} hours {minute_text} minutes {period}"

def num_to_words(n):
    # Dictionary to convert numbers to words for 0-59
    words = {
        0: "zero", 1: "one", 2: "two", 3: "three", 4: "four", 5: "five",
        6: "six", 7: "seven", 8: "eight", 9: "nine", 10: "ten",
        11: "eleven", 12: "twelve", 13: "thirteen", 14: "fourteen",
        15: "fifteen", 16: "sixteen", 17: "seventeen", 18: "eighteen",
        19: "nineteen", 20: "twenty", 21: "twenty-one", 22: "twenty-two",
        23: "twenty-three", 24: "twenty-four", 25: "twenty-five",
        26: "twenty-six", 27: "twenty-seven", 28: "twenty-eight",
        29: "twenty-nine", 30: "thirty", 31: "thirty-one", 32: "thirty-two",
        33: "thirty-three", 34: "thirty-four", 35: "thirty-five",
        36: "thirty-six", 37: "thirty-seven", 38: "thirty-eight",
        39: "thirty-nine", 40: "forty", 41: "forty-one", 42: "forty-two",
        43: "forty-three", 44: "forty-four", 45: "forty-five",
        46: "forty-six", 47: "forty-seven", 48: "forty-eight",
        49: "forty-nine", 50: "fifty", 51: "fifty-one", 52: "fifty-two",
        53: "fifty-three", 54: "fifty-four", 55: "fifty-five",
        56: "fifty-six", 57: "fifty-seven", 58: "fifty-eight",
        59: "fifty-nine"
    }
    return words.get(n, "")

# %%
def get_sensor_type(sensor_name):
    # Split by '-' and return the last part if there's a prefix
    return sensor_name.split('-')[-1]

# %%
len(ann_data_filtered)
# Out:
# 222858

# %%
sample_size = 222858

ann_data_small_sample = ann_data_filtered.sample(n=sample_size, random_state=42)
ann_data_small_sample
# Out:
#                          Timestamp Sensor_ID     Location        Zone State  \
# 269417  2012-09-10 07:25:46.488266     MA013   LivingRoom  LivingRoom   OFF
# 53209   2012-07-29 00:43:47.322359      M009      Bedroom     Bedroom   OFF
# 152162  2012-08-19 12:17:05.704754      M009      Bedroom     Bedroom   OFF
# 14527   2012-07-22 15:23:51.121630      M001  OutsideDoor       Entry   OFF
# 174050  2012-08-24 03:03:01.944014      M012      Bedroom         Bed    ON
# ...                            ...       ...          ...         ...   ...
# 174727  2012-08-24 05:51:34.499277      M012      Bedroom         Bed    ON
# 151004  2012-08-19 09:49:06.056731      M008   LivingRoom       Chair   OFF
# 192514  2012-08-27 17:47:36.224039     MA016      Kitchen     Kitchen   OFF
# 214063  2012-09-01 10:30:14.239079      M008   LivingRoom       Chair    ON
# 178011  2012-08-24 15:32:10.371527      M002      Kitchen     Kitchen    ON
#
#                 Sensor_Type        Activity
# 269417  Control4-MotionArea  Other_Activity
# 53209       Control4-Motion           Dress
# 152162      Control4-Motion  Other_Activity
# 14527       Control4-Motion      Leave_Home
# 174050      Control4-Motion           Sleep
# ...                     ...             ...
# 174727      Control4-Motion           Dress
# 151004      Control4-Motion        Watch_TV
# 192514  Control4-MotionArea     Cook_Dinner
# 214063      Control4-Motion        Watch_TV
# 178011      Control4-Motion     Wash_Dishes
#
# [222858 rows x 7 columns]

# %%
def get_activities_list(row):
    return row['Activity']

activity_labels_list = []
for index, row in ann_data_small_sample.iterrows():
    activity_labels_list.append(get_activities_list(row))

activity_labels_list
# Out:
# ['Other_Activity',
#  'Dress',
#  'Other_Activity',
#  'Leave_Home',
#  'Sleep',
#  'Sleep',
#  'Personal_Hygiene',
#  'Other_Activity',
#  'Cook_Breakfast',
#  'Toilet',
#  'Other_Activity',
#  'Sleep_Out_Of_Bed',
#  'Other_Activity',
#  'Bathe',
#  'Leave_Home',
#  'Watch_TV',
#  'Personal_Hygiene',
#  'Other_Activity',
#  'Other_Activity',
#  'Cook_Breakfast',
#  'Read',
#  'Watch_TV',
#  'Watch_TV',
#  'Leave_Home',
#  'Personal_Hygiene',
#  'Watch_TV',
#  'Other_Activity',
#  'Personal_Hygiene',
#  'Other_Activity',
#  'Sleep',
#  'Other_Activity',
#  'Other_Activity',
#  'Other_Activity',
#  'Watch_TV',
#  'Dress',
#  'Other_Activity',
#  'Other_Activity',
#  'Other_Activity',
#  'Cook_Breakfast',
#  'Dress',
#  'Other_Activity',
#  'Personal_Hygiene',
#  'Other_Activity',
#  'Other_Activity',
#  'Other_Activity',
#  'Cook',
#  'Watch_TV',
#  'Watch_TV',
#  'Bathe',
#  'Other_Activity',
#  'Watch_TV',
#  'Toilet',
#  'Eat_Breakfast',
#  'Cook_Breakfast',
#  'Cook_Breakfast',
#  'Watch_TV',
#  'Toilet',
#  'Other_Activity',
#  'Other_Activity',
#  'Watch_TV',
#  'Toilet',
#  'Other_Activity',
#  'Other_Activity',
#  'Personal_Hygiene',
#  'Other_Activity',
#  'Watch_TV',
#  'Personal_Hygiene',
#  'Other_Activity',
#  'Bed_Toilet_Transition',
#  'Other_Activity',
#  'Watch_TV',
#  'Cook_Dinner',
#  'Cook_Breakfast',
#  'Cook_Breakfast',
#  'Bathe',
#  'Bathe',
#  'Read',
#  'Cook_Breakfast',
#  'Personal_Hygiene',
#  'Watch_TV',
#  'Other_Activity',
#  'Other_Activity',
#  'Eat_Dinner',
#  'Dress',
#  'Cook_Breakfast',
#  'Watch_TV',
#  'Other_Activity',
#  'Other_Activity',
#  'Personal_Hygiene',
#  'Cook_Breakfast',
#  'Personal_Hygiene',
#  'Dress',
#  'Phone',
#  'Relax',
#  'Other_Activity',
#  'Wash_Breakfast_Dishes',
#  'Bathe',
#  'Watch_TV',
#  'Watch_TV',
#  'Relax',
#  'Cook_Breakfast',
#  'Other_Activity',
#  'Other_Activity',
#  'Cook_Dinner',
#  'Watch_TV',
#  'Personal_Hygiene',
#  'Other_Activity',
#  'Other_Activity',
#  'Sleep',
#  'Cook_Breakfast',
#  'Other_Activity',
#  'Cook',
#  'Dress',
#  'Bathe',
#  'Toilet',
#  'Dress',
#  'Dress',
#  'Read',
#  'Toilet',
#  'Other_Activity',
#  'Other_Activity',
#  'Dress',
#  'Other_Activity',
#  'Watch_TV',
#  'Watch_TV',
#  'Entertain_Guests',
#  'Personal_Hygiene',
#  'Bed_Toilet_Transition',
#  'Cook_Lunch',
#  'Personal_Hygiene',
#  'Other_Activity',
#  'Cook_Breakfast',
#  'Cook_Breakfast',
#  'Toilet',
#  'Relax',
#  'Other_Activity',
#  'Watch_TV',
#  'Watch_TV',
#  'Other_Activity',
#  'Evening_Meds',
#  'Sleep',
#  'Other_Activity',
#  'Other_Activity',
#  'Watch_TV',
#  'Dress',
#  'Personal_Hygiene',
#  'Other_Activity',
#  'Watch_TV',
#  'Bathe',
#  'Watch_TV',
#  'Dress',
#  'Other_Activity',
#  'Bathe',
#  'Wash_Dishes',
#  'Other_Activity',
#  'Toilet',
#  'Drink',
#  'Bed_Toilet_Transition',
#  'Watch_TV',
#  'Toilet',
#  'Dress',
#  'Other_Activity',
#  'Other_Activity',
#  'Bathe',
#  'Phone',
#  'Watch_TV',
#  'Other_Activity',
#  'Read',
#  'Other_Activity',
#  'Cook_Breakfast',
#  'Cook_Breakfast',
#  'Sleep_Out_Of_Bed',
#  'Sleep',
#  'Sleep',
#  'Watch_TV',
#  'Bathe',
#  'Other_Activity',
#  'Other_Activity',
#  'Toilet',
#  'Watch_TV',
#  'Other_Activity',
#  'Relax',
#  'Cook_Dinner',
#  'Relax',
#  'Other_Activity',
#  'Watch_TV',
#  'Read',
#  'Dress',
#  'Watch_TV',
#  'Other_Activity',
#  'Wash_Dinner_Dishes',
#  'Drink',
#  'Other_Activity',
#  'Read',
#  'Sleep',
#  'Other_Activity',
#  'Evening_Meds',
#  'Other_Activity',
#  'Watch_TV',
#  'Bathe',
#  'Read',
#  'Cook_Breakfast',
#  'Watch_TV',
#  'Dress',
#  'Entertain_Guests',
#  'Other_Activity',
#  'Dress',
#  'Dress',
#  'Other_Activity',
#  'Other_Activity',
#  'Step_Out',
#  'Other_Activity',
#  'Watch_TV',
#  'Dress',
#  'Watch_TV',
#  'Watch_TV',
#  'Other_Activity',
#  'Other_Activity',
#  'Other_Activity',
#  'Watch_TV',
#  'Drink',
#  'Other_Activity',
#  'Other_Activity',
#  'Toilet',
#  'Other_Activity',
#  'Other_Activity',
#  'Entertain_Guests',
#  'Eat_Dinner',
#  'Evening_Meds',
#  'Other_Activity',
#  'Other_Activity',
#  'Other_Activity',
#  'Other_Activity',
#  'Dress',
#  'Other_Activity',
#  'Eat_Lunch',
#  'Morning_Meds',
#  'Watch_TV',
#  'Bathe',
#  'Dress',
#  'Other_Activity',
#  'Morning_Meds',
#  'Step_Out',
#  'Other_Activity',
#  'Bathe',
#  'Other_Activity',
#  'Watch_TV',
#  'Dress',
#  'Watch_TV',
#  'Personal_Hygiene',
#  'Bathe',
#  'Other_Activity',
#  'Other_Activity',
#  'Watch_TV',
#  'Watch_TV',
#  'Bathe',
#  'Watch_TV',
#  'Watch_TV',
#  'Watch_TV',
#  'Go_To_Sleep',
#  'Dress',
#  'Watch_TV',
#  'Other_Activity',
#  'Toilet',
#  'Watch_TV',
#  'Watch_TV',
#  'Watch_TV',
#  'Watch_TV',
#  'Dress',
#  'Other_Activity',
#  'Other_Activity',
#  'Other_Activity',
#  'Watch_TV',
#  'Groom',
#  'Personal_Hygiene',
#  'Read',
#  'Other_Activity',
#  'Dress',
#  'Other_Activity',
#  'Cook_Breakfast',
#  'Personal_Hygiene',
#  'Cook_Dinner',
#  'Other_Activity',
#  'Other_Activity',
#  'Relax',
#  'Watch_TV',
#  'Other_Activity',
#  'Watch_TV',
#  'Wash_Dinner_Dishes',
#  'Watch_TV',
#  'Go_To_Sleep',
#  'Read',
#  'Read',
#  'Toilet',
#  'Bathe',
#  'Dress',
#  'Drink',
#  'Other_Activity',
#  'Relax',
#  'Watch_TV',
#  'Other_Activity',
#  'Bathe',
#  'Cook_Breakfast',
#  'Sleep_Out_Of_Bed',
#  'Other_Activity',
#  'Watch_TV',
#  'Cook',
#  'Other_Activity',
#  'Morning_Meds',
#  'Other_Activity',
#  'Enter_Home',
#  'Read',
#  'Other_Activity',
#  'Watch_TV',
#  'Other_Activity',
#  'Groom',
#  'Other_Activity',
#  'Watch_TV',
#  'Other_Activity',
#  'Cook_Breakfast',
#  'Morning_Meds',
#  'Wash_Dishes',
#  'Leave_Home',
#  'Cook_Breakfast',
#  'Sleep_Out_Of_Bed',
#  'Watch_TV',
#  'Cook',
#  'Watch_TV',
#  'Sleep_Out_Of_Bed',
#  'Entertain_Guests',
#  'Watch_TV',
#  'Other_Activity',
#  'Drink',
#  'Other_Activity',
#  'Step_Out',
#  'Other_Activity',
#  'Watch_TV',
#  'Other_Activity',
#  'Read',
#  'Phone',
#  'Other_Activity',
#  'Other_Activity',
#  'Other_Activity',
#  'Bathe',
#  'Relax',
#  'Watch_TV',
#  'Cook_Breakfast',
#  'Enter_Home',
#  'Other_Activity',
#  'Other_Activity',
#  'Watch_TV',
#  'Read',
#  'Cook_Breakfast',
#  'Sleep',
#  'Watch_TV',
#  'Other_Activity',
#  'Watch_TV',
#  'Cook_Breakfast',
#  'Other_Activity',
#  'Toilet',
#  'Cook_Breakfast',
#  'Bathe',
#  'Sleep',
#  'Cook_Breakfast',
#  'Toilet',
#  'Watch_TV',
#  'Cook_Breakfast',
#  'Watch_TV',
#  'Other_Activity',
#  'Other_Activity',
#  'Watch_TV',
#  'Wash_Lunch_Dishes',
#  'Morning_Meds',
#  'Watch_TV',
#  'Other_Activity',
#  'Watch_TV',
#  'Watch_TV',
#  'Dress',
#  'Read',
#  'Other_Activity',
#  'Sleep',
#  'Eat_Breakfast',
#  'Other_Activity',
#  'Bathe',
#  'Cook_Lunch',
#  'Other_Activity',
#  'Bathe',
#  'Entertain_Guests',
#  'Cook_Dinner',
#  'Wash_Breakfast_Dishes',
#  'Other_Activity',
#  'Cook_Breakfast',
#  'Dress',
#  'Watch_TV',
#  'Other_Activity',
#  'Watch_TV',
#  'Other_Activity',
#  'Morning_Meds',
#  'Other_Activity',
#  'Other_Activity',
#  'Personal_Hygiene',
#  'Watch_TV',
#  'Watch_TV',
#  'Wash_Breakfast_Dishes',
#  'Watch_TV',
#  'Personal_Hygiene',
#  'Other_Activity',
#  'Cook_Lunch',
#  'Cook_Breakfast',
#  'Enter_Home',
#  'Toilet',
#  'Watch_TV',
#  'Other_Activity',
#  'Watch_TV',
#  'Drink',
#  'Cook_Breakfast',
#  'Other_Activity',
#  'Cook',
#  'Cook_Dinner',
#  'Toilet',
#  'Sleep',
#  'Other_Activity',
#  'Other_Activity',
#  'Other_Activity',
#  'Bathe',
#  'Other_Activity',
#  'Relax',
#  'Phone',
#  'Leave_Home',
#  'Watch_TV',
#  'Other_Activity',
#  'Watch_TV',
#  'Watch_TV',
#  'Other_Activity',
#  'Other_Activity',
#  'Other_Activity',
#  'Drink',
#  'Other_Activity',
#  'Eat_Breakfast',
#  'Watch_TV',
#  'Bathe',
#  'Personal_Hygiene',
#  'Watch_TV',
#  'Toilet',
#  'Cook_Dinner',
#  'Cook_Breakfast',
#  'Cook_Breakfast',
#  'Watch_TV',
#  'Toilet',
#  'Other_Activity',
#  'Other_Activity',
#  'Cook_Breakfast',
#  'Bathe',
#  'Relax',
#  'Other_Activity',
#  'Wash_Breakfast_Dishes',
#  'Bathe',
#  'Morning_Meds',
#  'Other_Activity',
#  'Read',
#  'Bathe',
#  'Other_Activity',
#  'Eat_Breakfast',
#  'Watch_TV',
#  'Other_Activity',
#  'Toilet',
#  'Cook_Breakfast',
#  'Watch_TV',
#  'Other_Activity',
#  'Watch_TV',
#  'Other_Activity',
#  'Other_Activity',
#  'Relax',
#  'Entertain_Guests',
#  'Watch_TV',
#  'Eat_Lunch',
#  'Phone',
#  'Watch_TV',
#  'Other_Activity',
#  'Dress',
#  'Cook_Dinner',
#  'Toilet',
#  'Watch_TV',
#  'Wake_Up',
#  'Other_Activity',
#  'Evening_Meds',
#  'Watch_TV',
#  'Personal_Hygiene',
#  'Dress',
#  'Other_Activity',
#  'Personal_Hygiene',
#  'Step_Out',
#  'Watch_TV',
#  'Read',
#  'Watch_TV',
#  'Watch_TV',
#  'Other_Activity',
#  'Personal_Hygiene',
#  'Toilet',
#  'Bathe',
#  'Watch_TV',
#  'Other_Activity',
#  'Read',
#  'Phone',
#  'Personal_Hygiene',
#  'Bathe',
#  'Evening_Meds',
#  'Personal_Hygiene',
#  'Other_Activity',
#  'Enter_Home',
#  'Watch_TV',
#  'Eat_Breakfast',
#  'Watch_TV',
#  'Other_Activity',
#  'Relax',
#  'Other_Activity',
#  'Watch_TV',
#  'Cook',
#  'Watch_TV',
#  'Watch_TV',
#  'Other_Activity',
#  'Other_Activity',
#  'Sleep_Out_Of_Bed',
#  'Evening_Meds',
#  'Entertain_Guests',
#  'Watch_TV',
#  'Read',
#  'Watch_TV',
#  'Other_Activity',
#  'Personal_Hygiene',
#  'Dress',
#  'Other_Activity',
#  'Other_Activity',
#  'Eat_Breakfast',
#  'Wash_Breakfast_Dishes',
#  'Watch_TV',
#  'Other_Activity',
#  'Eat_Breakfast',
#  'Other_Activity',
#  'Watch_TV',
#  'Toilet',
#  'Entertain_Guests',
#  'Other_Activity',
#  'Relax',
#  'Relax',
#  'Personal_Hygiene',
#  'Cook_Breakfast',
#  'Personal_Hygiene',
#  'Sleep',
#  'Other_Activity',
#  'Bathe',
#  'Watch_TV',
#  'Other_Activity',
#  'Watch_TV',
#  'Groom',
#  'Enter_Home',
#  'Other_Activity',
#  'Other_Activity',
#  'Watch_TV',
#  'Bathe',
#  'Watch_TV',
#  'Watch_TV',
#  'Other_Activity',
#  'Other_Activity',
#  'Watch_TV',
#  'Cook_Lunch',
#  'Sleep',
#  'Morning_Meds',
#  'Bathe',
#  'Morning_Meds',
#  'Cook_Dinner',
#  'Watch_TV',
#  'Watch_TV',
#  'Read',
#  'Cook_Breakfast',
#  'Other_Activity',
#  'Cook_Dinner',
#  'Other_Activity',
#  'Watch_TV',
#  'Evening_Meds',
#  'Other_Activity',
#  'Toilet',
#  'Toilet',
#  'Bathe',
#  'Watch_TV',
#  'Cook_Breakfast',
#  'Watch_TV',
#  'Other_Activity',
#  'Other_Activity',
#  'Cook_Breakfast',
#  'Phone',
#  'Watch_TV',
#  'Bathe',
#  'Personal_Hygiene',
#  'Other_Activity',
#  'Other_Activity',
#  'Bathe',
#  'Bathe',
#  'Bathe',
#  'Watch_TV',
#  'Bathe',
#  'Relax',
#  'Dress',
#  'Watch_TV',
#  'Watch_TV',
#  'Morning_Meds',
#  'Toilet',
#  'Other_Activity',
#  'Wash_Dishes',
#  'Other_Activity',
#  'Sleep',
#  'Watch_TV',
#  'Personal_Hygiene',
#  'Other_Activity',
#  'Other_Activity',
#  'Other_Activity',
#  'Other_Activity',
#  'Watch_TV',
#  'Sleep_Out_Of_Bed',
#  'Other_Activity',
#  'Other_Activity',
#  'Other_Activity',
#  'Toilet',
#  'Cook',
#  'Other_Activity',
#  'Other_Activity',
#  'Other_Activity',
#  'Other_Activity',
#  'Cook_Breakfast',
#  'Other_Activity',
#  'Other_Activity',
#  'Leave_Home',
#  'Other_Activity',
#  'Toilet',
#  'Read',
#  'Personal_Hygiene',
#  'Step_Out',
#  'Watch_TV',
#  'Bathe',
#  'Dress',
#  'Watch_TV',
#  'Watch_TV',
#  'Other_Activity',
#  'Toilet',
#  'Sleep',
#  'Watch_TV',
#  'Bathe',
#  'Personal_Hygiene',
#  'Wash_Dishes',
#  'Dress',
#  'Sleep_Out_Of_Bed',
#  'Other_Activity',
#  'Watch_TV',
#  'Personal_Hygiene',
#  'Other_Activity',
#  'Other_Activity',
#  'Other_Activity',
#  'Other_Activity',
#  'Other_Activity',
#  'Personal_Hygiene',
#  'Personal_Hygiene',
#  'Other_Activity',
#  'Other_Activity',
#  'Wash_Breakfast_Dishes',
#  'Other_Activity',
#  'Watch_TV',
#  'Dress',
#  'Dress',
#  'Other_Activity',
#  'Watch_TV',
#  'Read',
#  'Bathe',
#  'Read',
#  'Other_Activity',
#  'Watch_TV',
#  'Watch_TV',
#  'Other_Activity',
#  'Dress',
#  'Other_Activity',
#  'Other_Activity',
#  'Other_Activity',
#  'Other_Activity',
#  'Watch_TV',
#  'Toilet',
#  'Cook_Breakfast',
#  'Sleep',
#  'Wash_Dinner_Dishes',
#  'Groom',
#  'Other_Activity',
#  'Other_Activity',
#  'Watch_TV',
#  'Wash_Dishes',
#  'Drink',
#  'Watch_TV',
#  'Personal_Hygiene',
#  'Other_Activity',
#  'Watch_TV',
#  'Other_Activity',
#  'Personal_Hygiene',
#  'Personal_Hygiene',
#  'Other_Activity',
#  'Cook_Breakfast',
#  'Other_Activity',
#  'Read',
#  'Other_Activity',
#  'Eat_Breakfast',
#  'Personal_Hygiene',
#  'Watch_TV',
#  'Watch_TV',
#  'Drink',
#  'Bathe',
#  'Toilet',
#  'Watch_TV',
#  'Other_Activity',
#  'Other_Activity',
#  'Read',
#  'Other_Activity',
#  'Personal_Hygiene',
#  'Cook_Dinner',
#  'Leave_Home',
#  'Other_Activity',
#  'Other_Activity',
#  'Watch_TV',
#  'Other_Activity',
#  'Personal_Hygiene',
#  'Watch_TV',
#  'Eat_Breakfast',
#  'Watch_TV',
#  'Cook_Breakfast',
#  'Bathe',
#  'Cook',
#  'Watch_TV',
#  'Other_Activity',
#  'Watch_TV',
#  'Dress',
#  'Sleep',
#  'Bathe',
#  'Other_Activity',
#  'Bathe',
#  'Read',
#  'Sleep',
#  'Bathe',
#  'Watch_TV',
#  'Cook_Breakfast',
#  'Wash_Breakfast_Dishes',
#  'Other_Activity',
#  'Other_Activity',
#  'Other_Activity',
#  'Cook_Breakfast',
#  'Sleep',
#  'Other_Activity',
#  'Watch_TV',
#  'Personal_Hygiene',
#  'Other_Activity',
#  'Watch_TV',
#  'Wash_Dishes',
#  'Toilet',
#  'Watch_TV',
#  'Wash_Breakfast_Dishes',
#  'Other_Activity',
#  'Cook_Dinner',
#  'Cook_Breakfast',
#  'Cook_Dinner',
#  'Bathe',
#  'Other_Activity',
#  'Watch_TV',
#  'Step_Out',
#  'Other_Activity',
#  'Other_Activity',
#  'Cook_Breakfast',
#  'Dress',
#  'Watch_TV',
#  'Personal_Hygiene',
#  'Relax',
#  'Toilet',
#  'Other_Activity',
#  'Watch_TV',
#  'Other_Activity',
#  'Watch_TV',
#  'Other_Activity',
#  'Watch_TV',
#  'Watch_TV',
#  'Eat_Breakfast',
#  'Personal_Hygiene',
#  'Other_Activity',
#  'Other_Activity',
#  'Cook_Lunch',
#  'Sleep_Out_Of_Bed',
#  'Toilet',
#  'Watch_TV',
#  'Dress',
#  'Other_Activity',
#  'Watch_TV',
#  'Read',
#  'Other_Activity',
#  'Step_Out',
#  'Watch_TV',
#  'Dress',
#  'Bathe',
#  'Dress',
#  'Other_Activity',
#  'Other_Activity',
#  'Cook_Breakfast',
#  'Other_Activity',
#  'Cook_Breakfast',
#  'Enter_Home',
#  'Watch_TV',
#  'Other_Activity',
#  'Toilet',
#  'Other_Activity',
#  'Other_Activity',
#  'Dress',
#  'Cook_Breakfast',
#  'Other_Activity',
#  'Cook_Lunch',
#  'Personal_Hygiene',
#  'Bed_Toilet_Transition',
#  'Other_Activity',
#  'Watch_TV',
#  'Cook_Dinner',
#  'Cook',
#  'Entertain_Guests',
#  'Other_Activity',
#  'Leave_Home',
#  'Eat_Lunch',
#  'Toilet',
#  'Watch_TV',
#  'Cook_Dinner',
#  'Cook_Breakfast',
#  'Other_Activity',
#  'Leave_Home',
#  'Watch_TV',
#  'Sleep_Out_Of_Bed',
#  'Wash_Dishes',
#  'Cook_Dinner',
#  'Other_Activity',
#  'Groom',
#  'Dress',
#  'Other_Activity',
#  'Read',
#  'Toilet',
#  'Drink',
#  'Phone',
#  'Watch_TV',
#  'Sleep',
#  'Leave_Home',
#  'Cook_Breakfast',
#  'Other_Activity',
#  'Other_Activity',
#  'Evening_Meds',
#  'Watch_TV',
#  'Evening_Meds',
#  'Toilet',
#  'Watch_TV',
#  'Other_Activity',
#  'Dress',
#  'Watch_TV',
#  'Watch_TV',
#  'Cook_Breakfast',
#  'Other_Activity',
#  'Relax',
#  'Other_Activity',
#  'Other_Activity',
#  'Other_Activity',
#  'Other_Activity',
#  'Eat_Lunch',
#  'Watch_TV',
#  'Sleep',
#  'Bathe',
#  'Other_Activity',
#  'Watch_TV',
#  'Morning_Meds',
#  'Watch_TV',
#  'Other_Activity',
#  'Cook_Breakfast',
#  'Dress',
#  'Personal_Hygiene',
#  'Other_Activity',
#  'Dress',
#  'Watch_TV',
#  'Eat',
#  'Toilet',
#  'Other_Activity',
#  'Watch_TV',
#  'Other_Activity',
#  'Watch_TV',
#  'Watch_TV',
#  'Watch_TV',
#  'Wash_Breakfast_Dishes',
#  'Toilet',
#  'Toilet',
#  'Drink',
#  'Cook_Breakfast',
#  'Other_Activity',
#  'Sleep',
#  'Watch_TV',
#  'Dress',
#  'Watch_TV',
#  'Dress',
#  'Watch_TV',
#  'Watch_TV',
#  'Toilet',
#  'Other_Activity',
#  'Drink',
#  'Personal_Hygiene',
#  'Personal_Hygiene',
#  'Cook_Breakfast',
#  'Other_Activity',
#  'Groom',
#  'Bathe',
#  'Personal_Hygiene',
#  'Sleep_Out_Of_Bed',
#  'Other_Activity',
#  'Wash_Dishes',
#  'Watch_TV',
#  'Watch_TV',
#  'Dress',
#  'Other_Activity',
#  'Relax',
#  'Dress',
#  'Bathe',
#  'Other_Activity',
#  'Dress',
#  'Toilet',
#  'Read',
#  'Watch_TV',
#  'Personal_Hygiene',
#  'Wash_Dishes',
#  'Other_Activity',
#  'Watch_TV',
#  'Other_Activity',
#  'Wash_Dishes',
#  'Sleep_Out_Of_Bed',
#  'Bathe',
#  'Sleep_Out_Of_Bed',
#  'Sleep',
#  'Morning_Meds',
#  'Eat_Lunch',
#  'Watch_TV',
#  'Bathe',
#  'Sleep',
#  'Sleep',
#  'Enter_Home',
#  'Cook_Breakfast',
#  'Cook_Breakfast',
#  'Bathe',
#  'Other_Activity',
#  'Watch_TV',
#  'Watch_TV',
#  'Other_Activity',
#  'Other_Activity',
#  'Dress',
#  'Bathe',
#  'Toilet',
#  'Other_Activity',
#  'Other_Activity',
#  'Dress',
#  'Other_Activity',
#  'Other_Activity',
#  'Watch_TV',
#  'Eat_Lunch',
#  'Watch_TV',
#  'Wash_Dishes',
#  'Watch_TV',
#  'Watch_TV',
#  'Read',
#  'Cook_Breakfast',
#  'Cook_Breakfast',
#  'Toilet',
#  'Watch_TV',
#  'Bed_Toilet_Transition',
#  'Read',
#  'Watch_TV',
#  'Watch_TV',
#  'Watch_TV',
#  'Cook_Breakfast',
#  'Dress',
#  'Watch_TV',
#  'Sleep',
#  'Cook',
#  'Other_Activity',
#  'Other_Activity',
#  'Toilet',
#  'Watch_TV',
#  'Other_Activity',
#  'Leave_Home',
#  'Sleep',
#  'Cook_Breakfast',
#  'Morning_Meds',
#  'Watch_TV',
#  'Toilet',
#  'Wash_Dinner_Dishes',
#  'Enter_Home',
#  'Other_Activity',
#  'Bathe',
#  'Watch_TV',
#  'Other_Activity',
#  'Watch_TV',
#  'Other_Activity',
#  'Personal_Hygiene',
#  ...]

# %%
# Generate TDOST descriptions
def generate_tdost(row):
    curr_time = pd.to_datetime(row['Timestamp'])
    day_of_week = curr_time.strftime('%A')
    time_period = get_time_period(curr_time.hour)
    sensor_type = get_sensor_type(row['Sensor_Type'])
    location = row['Location']
    state = row['State']
    return f"On {day_of_week} during the {time_period}, the {sensor_type} sensor in the {location} recorded a state of {state}."

# Apply TDOST generation to each row

tdost_basic_descriptions = []
for index, row in ann_data_small_sample.iterrows():
    tdost_basic_descriptions.append(generate_tdost(row))

tdost_basic_descriptions
# Out:
# ['On Monday during the Early Morning, the MotionArea sensor in the LivingRoom recorded a state of OFF.',
#  'On Sunday during the Night, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Sunday during the Afternoon, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Sunday during the Afternoon, the Motion sensor in the OutsideDoor recorded a state of OFF.',
#  'On Friday during the Night, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Saturday during the Early Morning, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Tuesday during the Late Night, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Friday during the Afternoon, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Monday during the Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Monday during the Morning, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Thursday during the Morning, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Wednesday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Thursday during the Morning, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Thursday during the Afternoon, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Sunday during the Afternoon, the MotionArea sensor in the LivingRoom recorded a state of ON.',
#  'On Sunday during the Late Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Afternoon, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Wednesday during the Morning, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Wednesday during the Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Sunday during the Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Saturday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Saturday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Sunday during the Late Night, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Friday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Monday during the Evening, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Friday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Friday during the Morning, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Wednesday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Tuesday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Saturday during the Night, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Wednesday during the Late Night, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Saturday during the Late Night, the Motion sensor in the DiningRoom recorded a state of OFF.',
#  'On Monday during the Afternoon, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Wednesday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Monday during the Morning, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Monday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Early Morning, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Saturday during the Afternoon, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Tuesday during the Morning, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Thursday during the Afternoon, the MotionArea sensor in the Bedroom recorded a state of ON.',
#  'On Tuesday during the Morning, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Monday during the Morning, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Tuesday during the Night, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Saturday during the Morning, the MotionArea sensor in the LivingRoom recorded a state of OFF.',
#  'On Friday during the Night, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Monday during the Late Night, the MotionArea sensor in the Kitchen recorded a state of OFF.',
#  'On Thursday during the Evening, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Wednesday during the Morning, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Friday during the Night, the Motion sensor in the OutsideDoor recorded a state of ON.',
#  'On Tuesday during the Evening, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Sunday during the Afternoon, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Friday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Early Morning, the MotionArea sensor in the Kitchen recorded a state of OFF.',
#  'On Saturday during the Morning, the MotionArea sensor in the Kitchen recorded a state of OFF.',
#  'On Friday during the Evening, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Friday during the Late Night, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Monday during the Evening, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Wednesday during the Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Sunday during the Late Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Friday during the Morning, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Monday during the Afternoon, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Sunday during the Afternoon, the MotionArea sensor in the LivingRoom recorded a state of OFF.',
#  'On Monday during the Late Night, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Tuesday during the Night, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Thursday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Saturday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Monday during the Evening, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Saturday during the Early Morning, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Wednesday during the Morning, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Friday during the Evening, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Thursday during the Evening, the MotionArea sensor in the Kitchen recorded a state of OFF.',
#  'On Tuesday during the Morning, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Friday during the Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Monday during the Morning, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Saturday during the Afternoon, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Monday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Monday during the Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Wednesday during the Late Night, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Thursday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Friday during the Late Night, the MotionArea sensor in the Bedroom recorded a state of ON.',
#  'On Tuesday during the Morning, the MotionArea sensor in the LivingRoom recorded a state of OFF.',
#  'On Thursday during the Evening, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Wednesday during the Morning, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Friday during the Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Friday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Thursday during the Evening, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Thursday during the Afternoon, the MotionArea sensor in the LivingRoom recorded a state of OFF.',
#  'On Monday during the Night, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Friday during the Early Morning, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Sunday during the Morning, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Tuesday during the Late Night, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Thursday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Wednesday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Night, the Motion sensor in the DiningRoom recorded a state of OFF.',
#  'On Sunday during the Morning, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Saturday during the Afternoon, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Friday during the Night, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Monday during the Evening, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Tuesday during the Morning, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Saturday during the Afternoon, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Monday during the Afternoon, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Friday during the Evening, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Friday during the Evening, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Sunday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Sunday during the Late Night, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Wednesday during the Morning, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Thursday during the Night, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Friday during the Early Morning, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Thursday during the Morning, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Monday during the Afternoon, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Monday during the Morning, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Saturday during the Afternoon, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Monday during the Morning, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Thursday during the Late Night, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Friday during the Afternoon, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Friday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Sunday during the Afternoon, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Thursday during the Morning, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Sunday during the Afternoon, the MotionArea sensor in the Bedroom recorded a state of ON.',
#  'On Saturday during the Evening, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Sunday during the Evening, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Wednesday during the Night, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Tuesday during the Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Tuesday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Sunday during the Night, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Tuesday during the Afternoon, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Sunday during the Late Night, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Wednesday during the Morning, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Tuesday during the Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Thursday during the Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Tuesday during the Afternoon, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Saturday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Tuesday during the Afternoon, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Sunday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Tuesday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Tuesday during the Night, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Wednesday during the Evening, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Tuesday during the Night, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Tuesday during the Morning, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Wednesday during the Late Night, the MotionArea sensor in the LivingRoom recorded a state of ON.',
#  'On Thursday during the Late Night, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Tuesday during the Night, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Saturday during the Morning, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Monday during the Late Night, the MotionArea sensor in the Bedroom recorded a state of ON.',
#  'On Tuesday during the Late Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Thursday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Friday during the Late Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Friday during the Night, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Saturday during the Evening, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Wednesday during the Morning, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Wednesday during the Late Night, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Friday during the Evening, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Sunday during the Afternoon, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Wednesday during the Evening, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Saturday during the Night, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Friday during the Evening, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Tuesday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Monday during the Morning, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Wednesday during the Evening, the MotionArea sensor in the LivingRoom recorded a state of ON.',
#  'On Friday during the Morning, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Tuesday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Saturday during the Evening, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Monday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Wednesday during the Early Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Wednesday during the Late Night, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Friday during the Morning, the MotionArea sensor in the Kitchen recorded a state of OFF.',
#  'On Saturday during the Morning, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Sunday during the Evening, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Late Night, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Wednesday during the Night, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Monday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Monday during the Morning, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Wednesday during the Evening, the MotionArea sensor in the LivingRoom recorded a state of ON.',
#  'On Sunday during the Morning, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Friday during the Morning, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Monday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Monday during the Afternoon, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Friday during the Night, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Wednesday during the Evening, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Friday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Monday during the Evening, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Wednesday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Thursday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Friday during the Night, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Monday during the Late Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Thursday during the Afternoon, the MotionArea sensor in the Bedroom recorded a state of ON.',
#  'On Friday during the Evening, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Monday during the Afternoon, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Thursday during the Afternoon, the MotionArea sensor in the LivingRoom recorded a state of OFF.',
#  'On Sunday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Wednesday during the Night, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Friday during the Evening, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Thursday during the Late Night, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Monday during the Afternoon, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Friday during the Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Sunday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Sunday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Monday during the Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Tuesday during the Late Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Night, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Thursday during the Morning, the Motion sensor in the OutsideDoor recorded a state of ON.',
#  'On Wednesday during the Morning, the Motion sensor in the OutsideDoor recorded a state of OFF.',
#  'On Friday during the Morning, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Monday during the Morning, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Monday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Thursday during the Morning, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Sunday during the Afternoon, the Door sensor in the OutsideDoor recorded a state of CLOSE.',
#  'On Wednesday during the Morning, the MotionArea sensor in the Bedroom recorded a state of ON.',
#  'On Saturday during the Evening, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Monday during the Late Night, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Tuesday during the Evening, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Tuesday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Wednesday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Thursday during the Morning, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Thursday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Friday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Late Night, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Wednesday during the Morning, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Monday during the Afternoon, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Tuesday during the Early Morning, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Saturday during the Afternoon, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Monday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Thursday during the Morning, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Sunday during the Evening, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Sunday during the Late Night, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Thursday during the Afternoon, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Wednesday during the Morning, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Friday during the Morning, the Motion sensor in the DiningRoom recorded a state of ON.',
#  'On Wednesday during the Morning, the MotionArea sensor in the Bedroom recorded a state of ON.',
#  'On Monday during the Late Night, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Thursday during the Afternoon, the Motion sensor in the OutsideDoor recorded a state of ON.',
#  'On Thursday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Friday during the Morning, the MotionArea sensor in the Kitchen recorded a state of OFF.',
#  'On Thursday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Tuesday during the Morning, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Thursday during the Morning, the MotionArea sensor in the Bedroom recorded a state of ON.',
#  'On Friday during the Early Morning, the MotionArea sensor in the Bedroom recorded a state of ON.',
#  'On Sunday during the Morning, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Thursday during the Late Night, the MotionArea sensor in the LivingRoom recorded a state of ON.',
#  'On Sunday during the Afternoon, the MotionArea sensor in the LivingRoom recorded a state of OFF.',
#  'On Saturday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Wednesday during the Evening, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Saturday during the Late Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Tuesday during the Night, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Wednesday during the Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Monday during the Late Night, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Saturday during the Afternoon, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Friday during the Morning, the Motion sensor in the OutsideDoor recorded a state of ON.',
#  'On Monday during the Morning, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Thursday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Saturday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Saturday during the Afternoon, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Sunday during the Late Night, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Monday during the Evening, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Wednesday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Tuesday during the Night, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Friday during the Morning, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Friday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Monday during the Evening, the MotionArea sensor in the LivingRoom recorded a state of OFF.',
#  'On Wednesday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Sunday during the Evening, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Friday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Monday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Friday during the Night, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Tuesday during the Afternoon, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Friday during the Morning, the MotionArea sensor in the Bedroom recorded a state of ON.',
#  'On Tuesday during the Early Morning, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Tuesday during the Late Night, the MotionArea sensor in the LivingRoom recorded a state of ON.',
#  'On Wednesday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Monday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Friday during the Evening, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Tuesday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Monday during the Afternoon, the MotionArea sensor in the LivingRoom recorded a state of ON.',
#  'On Friday during the Evening, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Tuesday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Thursday during the Early Morning, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Sunday during the Late Night, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Saturday during the Evening, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Wednesday during the Morning, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Wednesday during the Late Night, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Monday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Evening, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Friday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Friday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Night, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Thursday during the Evening, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Wednesday during the Night, the MotionArea sensor in the Bedroom recorded a state of ON.',
#  'On Monday during the Early Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Thursday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Early Morning, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Saturday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Monday during the Afternoon, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Wednesday during the Evening, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Monday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Thursday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Saturday during the Evening, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Sunday during the Night, the MotionArea sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Afternoon, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Thursday during the Early Morning, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Friday during the Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Friday during the Late Night, the MotionArea sensor in the Bedroom recorded a state of ON.',
#  'On Friday during the Evening, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Monday during the Afternoon, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Wednesday during the Morning, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Monday during the Early Morning, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Wednesday during the Morning, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Friday during the Afternoon, the Door sensor in the OutsideDoor recorded a state of OPEN.',
#  'On Tuesday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Wednesday during the Morning, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Friday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Wednesday during the Late Night, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Monday during the Morning, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Saturday during the Afternoon, the MotionArea sensor in the Bedroom recorded a state of ON.',
#  'On Friday during the Evening, the MotionArea sensor in the LivingRoom recorded a state of ON.',
#  'On Sunday during the Late Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Monday during the Morning, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Tuesday during the Early Morning, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Wednesday during the Night, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Monday during the Evening, the Motion sensor in the OutsideDoor recorded a state of ON.',
#  'On Friday during the Morning, the MotionArea sensor in the Kitchen recorded a state of OFF.',
#  'On Tuesday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Sunday during the Late Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Sunday during the Late Night, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Tuesday during the Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Sunday during the Evening, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Thursday during the Morning, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Wednesday during the Night, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Wednesday during the Late Night, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Tuesday during the Afternoon, the MotionArea sensor in the Kitchen recorded a state of OFF.',
#  'On Friday during the Morning, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Tuesday during the Afternoon, the Motion sensor in the OutsideDoor recorded a state of OFF.',
#  'On Friday during the Morning, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Wednesday during the Evening, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Sunday during the Early Morning, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Monday during the Early Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Tuesday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Friday during the Afternoon, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Saturday during the Morning, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Monday during the Early Morning, the MotionArea sensor in the LivingRoom recorded a state of ON.',
#  'On Wednesday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Monday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Sunday during the Evening, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Thursday during the Morning, the MotionArea sensor in the Kitchen recorded a state of OFF.',
#  'On Thursday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Tuesday during the Early Morning, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Tuesday during the Morning, the MotionArea sensor in the Bedroom recorded a state of ON.',
#  'On Saturday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Tuesday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Tuesday during the Morning, the MotionArea sensor in the Kitchen recorded a state of OFF.',
#  'On Monday during the Night, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Thursday during the Late Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Friday during the Morning, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Wednesday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Thursday during the Morning, the MotionArea sensor in the Kitchen recorded a state of OFF.',
#  'On Tuesday during the Morning, the MotionArea sensor in the Bedroom recorded a state of ON.',
#  'On Thursday during the Early Morning, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Thursday during the Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Wednesday during the Morning, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Wednesday during the Night, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Monday during the Early Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Saturday during the Early Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Sunday during the Evening, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Wednesday during the Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Wednesday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Wednesday during the Morning, the MotionArea sensor in the Bedroom recorded a state of ON.',
#  'On Wednesday during the Evening, the MotionArea sensor in the Kitchen recorded a state of OFF.',
#  'On Saturday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Saturday during the Afternoon, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Saturday during the Early Morning, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Sunday during the Evening, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Friday during the Night, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Tuesday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Monday during the Late Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Tuesday during the Late Night, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Wednesday during the Early Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Thursday during the Morning, the Motion sensor in the OutsideDoor recorded a state of ON.',
#  'On Saturday during the Early Morning, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Wednesday during the Early Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Wednesday during the Morning, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Thursday during the Afternoon, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Tuesday during the Afternoon, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Saturday during the Evening, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Monday during the Afternoon, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Thursday during the Morning, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Friday during the Evening, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Friday during the Morning, the MotionArea sensor in the Kitchen recorded a state of OFF.',
#  'On Friday during the Evening, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Friday during the Early Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Thursday during the Afternoon, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Friday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Saturday during the Late Night, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Monday during the Late Night, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Thursday during the Late Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Morning, the MotionArea sensor in the Kitchen recorded a state of OFF.',
#  'On Friday during the Evening, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Tuesday during the Evening, the MotionArea sensor in the Bedroom recorded a state of ON.',
#  'On Monday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Thursday during the Late Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Monday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Monday during the Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Friday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Wednesday during the Morning, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Wednesday during the Morning, the MotionArea sensor in the LivingRoom recorded a state of ON.',
#  'On Tuesday during the Afternoon, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Sunday during the Early Morning, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Thursday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Monday during the Afternoon, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Tuesday during the Evening, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Tuesday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Sunday during the Late Night, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Wednesday during the Evening, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Sunday during the Morning, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Wednesday during the Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Monday during the Evening, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Wednesday during the Evening, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Thursday during the Evening, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Friday during the Night, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Wednesday during the Morning, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Tuesday during the Evening, the Motion sensor in the OutsideDoor recorded a state of OFF.',
#  'On Tuesday during the Afternoon, the MotionArea sensor in the LivingRoom recorded a state of OFF.',
#  'On Tuesday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Sunday during the Late Night, the Motion sensor in the DiningRoom recorded a state of ON.',
#  'On Thursday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Thursday during the Early Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Tuesday during the Afternoon, the Motion sensor in the OutsideDoor recorded a state of ON.',
#  'On Sunday during the Evening, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Wednesday during the Afternoon, the Motion sensor in the OutsideDoor recorded a state of ON.',
#  'On Thursday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Wednesday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Evening, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Saturday during the Night, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Friday during the Early Morning, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Sunday during the Afternoon, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Saturday during the Late Night, the Motion sensor in the OutsideDoor recorded a state of ON.',
#  'On Wednesday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Sunday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Wednesday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Friday during the Evening, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Monday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Thursday during the Evening, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Friday during the Evening, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Tuesday during the Morning, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Monday during the Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Thursday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Thursday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Saturday during the Afternoon, the MotionArea sensor in the Bedroom recorded a state of ON.',
#  'On Sunday during the Late Night, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Thursday during the Morning, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Monday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Sunday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Tuesday during the Morning, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Monday during the Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Saturday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Wednesday during the Early Morning, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Wednesday during the Late Night, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Saturday during the Early Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Afternoon, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Monday during the Late Night, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Wednesday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Thursday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Late Night, the MotionArea sensor in the LivingRoom recorded a state of ON.',
#  'On Sunday during the Morning, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Wednesday during the Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Sunday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Friday during the Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Monday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Monday during the Late Night, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Thursday during the Afternoon, the MotionArea sensor in the Bedroom recorded a state of ON.',
#  'On Thursday during the Evening, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Friday during the Morning, the Motion sensor in the OutsideDoor recorded a state of OFF.',
#  'On Monday during the Late Night, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Wednesday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Thursday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Monday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Thursday during the Morning, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Monday during the Late Night, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Friday during the Evening, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Thursday during the Afternoon, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Sunday during the Late Night, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Wednesday during the Early Morning, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Saturday during the Afternoon, the MotionArea sensor in the LivingRoom recorded a state of ON.',
#  'On Tuesday during the Evening, the MotionArea sensor in the Kitchen recorded a state of OFF.',
#  'On Friday during the Late Night, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Tuesday during the Late Night, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Tuesday during the Morning, the MotionArea sensor in the Bedroom recorded a state of ON.',
#  'On Saturday during the Late Night, the MotionArea sensor in the Bedroom recorded a state of ON.',
#  'On Tuesday during the Late Night, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Friday during the Afternoon, the Motion sensor in the OutsideDoor recorded a state of ON.',
#  'On Saturday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Saturday during the Early Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Monday during the Evening, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Friday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Monday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
# ...
#  'On Wednesday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Tuesday during the Afternoon, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Monday during the Late Night, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Friday during the Morning, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Tuesday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Thursday during the Afternoon, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Thursday during the Late Night, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Saturday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Saturday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Friday during the Night, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Monday during the Afternoon, the Motion sensor in the OutsideDoor recorded a state of ON.',
#  'On Tuesday during the Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Friday during the Afternoon, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Sunday during the Late Night, the MotionArea sensor in the LivingRoom recorded a state of OFF.',
#  'On Thursday during the Late Night, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Thursday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Tuesday during the Night, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Tuesday during the Early Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Monday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Wednesday during the Morning, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Wednesday during the Late Night, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Saturday during the Late Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Wednesday during the Night, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Tuesday during the Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Tuesday during the Morning, the MotionArea sensor in the LivingRoom recorded a state of ON.',
#  'On Monday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Monday during the Afternoon, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Saturday during the Late Night, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Saturday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Sunday during the Night, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Saturday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Monday during the Evening, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Wednesday during the Night, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Monday during the Afternoon, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Tuesday during the Early Morning, the Motion sensor in the OutsideDoor recorded a state of OFF.',
#  'On Saturday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Sunday during the Early Morning, the MotionArea sensor in the Kitchen recorded a state of OFF.',
#  'On Wednesday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Wednesday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Thursday during the Morning, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Monday during the Late Night, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Sunday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Wednesday during the Morning, the MotionArea sensor in the Bedroom recorded a state of ON.',
#  'On Wednesday during the Afternoon, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Tuesday during the Late Night, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Saturday during the Late Night, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Wednesday during the Early Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Sunday during the Afternoon, the Motion sensor in the DiningRoom recorded a state of ON.',
#  'On Sunday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Sunday during the Late Night, the MotionArea sensor in the Bedroom recorded a state of ON.',
#  'On Thursday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Wednesday during the Night, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Thursday during the Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Friday during the Evening, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Friday during the Morning, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Sunday during the Morning, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Sunday during the Morning, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Thursday during the Afternoon, the MotionArea sensor in the LivingRoom recorded a state of ON.',
#  'On Friday during the Early Morning, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Friday during the Night, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Saturday during the Evening, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Sunday during the Late Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Thursday during the Late Night, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Wednesday during the Evening, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Tuesday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Tuesday during the Night, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Saturday during the Late Night, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Saturday during the Late Night, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Thursday during the Morning, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Friday during the Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Friday during the Afternoon, the MotionArea sensor in the LivingRoom recorded a state of OFF.',
#  'On Wednesday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Monday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Thursday during the Night, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Sunday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Wednesday during the Evening, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Friday during the Afternoon, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Sunday during the Late Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Monday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Monday during the Morning, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Friday during the Late Night, the MotionArea sensor in the LivingRoom recorded a state of ON.',
#  'On Monday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Wednesday during the Afternoon, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Saturday during the Afternoon, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Sunday during the Evening, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Afternoon, the MotionArea sensor in the Bedroom recorded a state of ON.',
#  'On Monday during the Late Night, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Sunday during the Early Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Thursday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Sunday during the Night, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Friday during the Evening, the MotionArea sensor in the Kitchen recorded a state of OFF.',
#  'On Saturday during the Early Morning, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Tuesday during the Evening, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Tuesday during the Morning, the Motion sensor in the OutsideDoor recorded a state of ON.',
#  'On Monday during the Late Night, the MotionArea sensor in the Kitchen recorded a state of OFF.',
#  'On Friday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Saturday during the Afternoon, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Saturday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Thursday during the Night, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Friday during the Early Morning, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Sunday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Late Night, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Saturday during the Afternoon, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Monday during the Night, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Sunday during the Late Night, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Monday during the Evening, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Tuesday during the Morning, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Tuesday during the Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Wednesday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Monday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Friday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Monday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Afternoon, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Saturday during the Afternoon, the MotionArea sensor in the LivingRoom recorded a state of OFF.',
#  'On Sunday during the Morning, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Friday during the Morning, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Sunday during the Evening, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Sunday during the Late Night, the MotionArea sensor in the LivingRoom recorded a state of ON.',
#  'On Tuesday during the Morning, the MotionArea sensor in the LivingRoom recorded a state of ON.',
#  'On Tuesday during the Late Night, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Wednesday during the Night, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Saturday during the Afternoon, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Monday during the Late Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Thursday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Sunday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Sunday during the Late Night, the MotionArea sensor in the Kitchen recorded a state of ON.',
#  'On Tuesday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Saturday during the Late Night, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Sunday during the Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Monday during the Morning, the MotionArea sensor in the Kitchen recorded a state of OFF.',
#  'On Sunday during the Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Tuesday during the Evening, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Friday during the Late Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Friday during the Night, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Tuesday during the Morning, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Saturday during the Morning, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Sunday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Thursday during the Late Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Thursday during the Morning, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Tuesday during the Afternoon, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Tuesday during the Evening, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Sunday during the Night, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Sunday during the Late Night, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Saturday during the Afternoon, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Sunday during the Late Night, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Thursday during the Evening, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Wednesday during the Afternoon, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Wednesday during the Morning, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Monday during the Evening, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Thursday during the Night, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Saturday during the Early Morning, the Motion sensor in the Kitchen recorded a state of OFF.',
#  'On Thursday during the Morning, the MotionArea sensor in the Kitchen recorded a state of OFF.',
#  'On Monday during the Late Night, the Motion sensor in the LivingRoom recorded a state of ON.',
#  'On Friday during the Morning, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  'On Saturday during the Evening, the Motion sensor in the Kitchen recorded a state of ON.',
#  'On Saturday during the Evening, the MotionArea sensor in the LivingRoom recorded a state of ON.',
#  'On Thursday during the Morning, the Motion sensor in the Bedroom recorded a state of ON.',
#  'On Friday during the Morning, the MotionArea sensor in the Bathroom recorded a state of OFF.',
#  'On Tuesday during the Night, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Wednesday during the Morning, the Motion sensor in the Bedroom recorded a state of OFF.',
#  'On Wednesday during the Evening, the Motion sensor in the LivingRoom recorded a state of OFF.',
#  'On Saturday during the Afternoon, the MotionArea sensor in the Bedroom recorded a state of OFF.',
#  'On Friday during the Evening, the MotionArea sensor in the Bathroom recorded a state of ON.',
#  ...]

# %%
# Generate TDOST temporal descriptions
def generate_tdost_temporal(row):
    time_in_words = timestamp_to_words(row['Timestamp'])
    sensor_type = get_sensor_type(row['Sensor_Type'])
    location = row['Location']
    state = row['State']
    return f"{sensor_type} sensor in the {location} fired with value {state} at {time_in_words}."

# Apply TDOST generation to each row

tdost_temporal_descriptions = ann_data_small_sample.apply(generate_tdost_temporal, axis=1)
tdost_temporal_descriptions
# Out:
# 269417    MotionArea sensor in the LivingRoom fired with...
# 53209     Motion sensor in the Bedroom fired with value ...
# 152162    Motion sensor in the Bedroom fired with value ...
# 14527     Motion sensor in the OutsideDoor fired with va...
# 174050    Motion sensor in the Bedroom fired with value ...
#                                 ...
# 185137    Motion sensor in the Kitchen fired with value ...
# 319604    Motion sensor in the LivingRoom fired with val...
# 188602    MotionArea sensor in the Bathroom fired with v...
# 50773     Motion sensor in the Bedroom fired with value ...
# 238901    MotionArea sensor in the Bathroom fired with v...
# Length: 50000, dtype: object

# %%
from sentence_transformers import SentenceTransformer

# Load a pre-trained Sentence-BERT model for generating embeddings
# model = SentenceTransformer('all-mpnet-base-v2')
model = SentenceTransformer('all-distilroberta-v1')
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Encode TDOST descriptions
tdost_descriptions_embeddings = model.encode(tdost_basic_descriptions, batch_size=128, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/1742 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 6
#       2 tdost_descriptions_embeddings = model.encode(tdost_basic_descriptions, batch_size=128, show_progress_bar=True)
#       5 # Encode labels for each TDOST description
# ----> 6 encoded_labels = label_encoder.transform(activity_labels_list)  # Should have length of 50,000
#       9 # Now you can verify lengths
#      10 print("Length of TDOST Descriptions Embeddings:", len(tdost_descriptions_embeddings)) # Should be 50,000
#
# NameError: name 'label_encoder' is not defined

# %%
# Encode labels for each TDOST description
label_encoder = LabelEncoder()

# Step 2: Fit and transform the activity labels
# Assuming `df['activity']` contains the activity labels
ann_data_small_sample['encoded_activity'] = label_encoder.fit_transform(activity_labels_list)

# Display the original and encoded labels
print(ann_data_small_sample[['Activity', 'encoded_activity']].head())
# Out:
#               Activity  encoded_activity
# 269417  Other_Activity                19
# 53209            Dress                 6
# 152162  Other_Activity                19
# 14527       Leave_Home                17
# 174050           Sleep                24

# %%
import torch


# Convert to PyTorch tensors
tdost_embeddings_tensor = torch.tensor(tdost_descriptions_embeddings)
encoded_labels_tensor = torch.tensor(ann_data_small_sample['encoded_activity'].tolist())

# %%
from sklearn.model_selection import train_test_split

# Split the dataset into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(tdost_embeddings_tensor, encoded_labels_tensor, test_size=0.2, random_state=42)

X_train_2, X_val_2, y_train_2, y_val_2 = train_test_split(tdost_descriptions_embeddings, ann_data_small_sample['encoded_activity'].tolist(), test_size=0.2, random_state=43)

# Print the sizes of the training and validation sets
print("Training set size:", len(X_train))
print("Validation set size:", len(X_val))
# Out:
# Training set size: 178286
# Validation set size: 44572

# %%
# Add sequence length dimension
X_train = X_train.unsqueeze(1)  # Shape: (num_samples, 1, input_size)
X_val = X_val.unsqueeze(1)      # Shape: (num_samples, 1, input_size)

# %%
class BiLSTM(torch.nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(BiLSTM, self).__init__()
        self.lstm = torch.nn.LSTM(input_size, hidden_size, bidirectional=True, batch_first=True)
        self.fc = torch.nn.Linear(hidden_size * 2, output_size)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])  # Use the last output
        return out

# Initialize the model
input_size = tdost_embeddings_tensor.shape[1]  # Embedding size (e.g., 768)
hidden_size = 64  # You can adjust this
output_size = len(label_encoder.classes_)  # Number of unique activities

model = BiLSTM(input_size, hidden_size, output_size)

# %%
# Define the loss function and optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
num_epochs = 650  # Number of epochs

for epoch in range(num_epochs):
    model.train()  # Set the model to training mode
    optimizer.zero_grad()  # Clear previous gradients

    # Forward pass
    outputs = model(X_train.float())  # Pass the training data through the model
    loss = criterion(outputs, y_train)  # Calculate the loss

    # Backward pass and optimization
    loss.backward()  # Compute gradients
    optimizer.step()  # Update model parameters

    # Print the loss every epoch
    if (epoch + 1) % 1 == 0:  # Print every epoch
        print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1
# Epoch [618/650], Loss: 1.1304
# Epoch [619/650], Loss: 1.1302
# Epoch [620/650], Loss: 1.1301
# Epoch [621/650], Loss: 1.1299
# Epoch [622/650], Loss: 1.1297
# Epoch [623/650], Loss: 1.1296
# Epoch [624/650], Loss: 1.1294
# Epoch [625/650], Loss: 1.1292
# Epoch [626/650], Loss: 1.1291
# Epoch [627/650], Loss: 1.1289
# Epoch [628/650], Loss: 1.1287
# Epoch [629/650], Loss: 1.1286
# Epoch [630/650], Loss: 1.1284
# Epoch [631/650], Loss: 1.1282
# Epoch [632/650], Loss: 1.1281
# Epoch [633/650], Loss: 1.1279
# Epoch [634/650], Loss: 1.1277
# Epoch [635/650], Loss: 1.1276
# Epoch [636/650], Loss: 1.1274
# Epoch [637/650], Loss: 1.1273
# Epoch [638/650], Loss: 1.1271
# Epoch [639/650], Loss: 1.1269
# Epoch [640/650], Loss: 1.1268
# Epoch [641/650], Loss: 1.1266
# Epoch [642/650], Loss: 1.1265
# Epoch [643/650], Loss: 1.1263
# Epoch [644/650], Loss: 1.1261
# Epoch [645/650], Loss: 1.1260
# Epoch [646/650], Loss: 1.1258
# Epoch [647/650], Loss: 1.1257
# Epoch [648/650], Loss: 1.1255
# Epoch [649/650], Loss: 1.1254
# Epoch [650/650], Loss: 1.1252

# %%
model.eval()  # Set the model to evaluation mode
with torch.no_grad():
    val_outputs = model(X_val.float())
    _, predicted = torch.max(val_outputs.data, 1)

    # Calculate accuracy
    accuracy = (predicted == y_val).sum().item() / y_val.size(0)
    print(f'Validation Accuracy: {accuracy:.4f}')
# Out:
# Validation Accuracy: 0.6170

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report


# Train a classifier
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train_2, y_train_2)

# Evaluate on test set
y_pred = clf.predict(X_val_2)
print(classification_report(y_val_2, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.81      0.61      2343
#            1       0.00      0.00      0.00       133
#            2       0.47      0.14      0.22       433
#            3       0.57      0.99      0.73      2406
#            4       0.55      0.91      0.69       883
#            5       0.35      0.56      0.43       450
#            6       0.49      0.09      0.16      2206
#            7       0.39      0.04      0.08       608
#            8       0.00      0.00      0.00        78
#            9       0.00      0.00      0.00       472
#           10       0.00      0.00      0.00       189
#           11       0.00      0.00      0.00       127
#           12       0.33      0.08      0.13       423
#           13       0.40      0.01      0.01       358
#           14       0.39      0.80      0.52       505
#           15       0.00      0.00      0.00        76
#           16       0.00      0.00      0.00       254
#           17       0.30      0.04      0.07       538
#           18       0.57      0.06      0.10       539
#           19       0.69      0.72      0.71     12315
#           20       0.68      0.49      0.57      1923
#           21       0.00      0.00      0.00       244
#           22       0.65      0.47      0.54      1025
#           23       0.00      0.00      0.00       722
#           24       0.59      0.69      0.64      1351
#           25       0.00      0.00      0.00       832
#           26       0.00      0.00      0.00       212
#           27       0.54      0.45      0.49      2331
#           28       0.00      0.00      0.00        69
#           29       0.00      0.00      0.00       502
#           30       0.00      0.00      0.00       409
#           31       0.28      0.05      0.09       493
#           32       0.00      0.00      0.00       137
#           33       0.64      0.99      0.78      8963
#           34       0.00      0.00      0.00        23
#
#     accuracy                           0.61     44572
#    macro avg       0.27      0.24      0.22     44572
# weighted avg       0.54      0.61      0.55     44572
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
